# %%
import camelot
import pandas as pd
import openpyxl
import os
import pdfplumber
import re
# tables = camelot.read_pdf('epd1388_2021.pdf', pages='10',process_background=True)
# tables = camelot.read_pdf('./IBU-09-20/New/14632.pdf', pages='6', split_text=True,table_areas=["69.60548391889084,500.088593765987,525.3099336281931,403.96614296894364"])
# print(len(tables))

# tables = camelot.read_pdf('./New/14699.pdf', pages='all')
# print(len(tables))

# %%
# columns = {                                                                                                   
#   "impactGWP100_kgCO2e": "(^Global warming potential - total$)|(^Globales Erwärmungspotenzial - total$)|(^Global warming potential \xad total$)|(^GWP-total$)|(^GWP$)|(^Global warming potential$)|(^Globales Erwärmungspotenzial ­ total$)|(^Globales Erwärmungspotenzial$)",
#   "impactODP_kgCFC11e": "(^ODP$)|(^Abbaupotenzial der stratosphärischen Ozonschicht$)|(^Depletion potential of the stratospheric ozone layer$)",
#   "impactAP_kgSO2e": "(^AP$)|(^AP Air$)|(^Versauerungspotenzial von Boden und Wasser$)|(^Acidification potential of land and water$)",
#   "impactEP_kgPO4e": "(^Eutrophication, fraction of nutrients reaching freshwater \nend compartment$)|(^EP-freshwater$)|(^EP$)|(^Eutrophierungspotenzial$)|(^Eutrophication potential)",
#   "impactPOCP_kgEthenee": "(^POCP$)|(^Bildungspotenzial für troposphärisches Ozon$)|(^Formation potential of tropospheric ozone photochemical \noxidants)",
#   "impactADPElements_kgSbe": "(^Abiotic depletion potential for non\xadfossil resources$)|(^ADPE$)|(^Potenzial für die Verknappung abiotischer Ressourcen \xad \nnicht fossile Ressourcen$)|(^Potenzial für die Verknappung abiotischer Ressourcen - \nnicht fossile Ressourcen$)|(^Abiotic depletion potential for non-fossil resources)",
#   "impactADPFossilFuels_MJ": "(^ADPF$)|(^Potenzial für die Verknappung abiotischer Ressourcen \xad \nfossile Brennstoffe$)|(^Potenzial für die Verknappung abiotischer Ressourcen - \nfossile Brennstoffe$)|(^Abiotic depletion potential for fossil resources)",
    
#   "renewablesUsedAsEnergy_MJ": "(^PERE$)|(^Erneuerbare Primärenergie als Energieträger$)|(^Renewable primary energy as energy carrier$)",
#   "renewablesUsedAsMaterial_MJ": "(^PERM$)|(^Erneuerbare Primärenergie zur stofflichen Nutzung$)|(^Renewable primary energy resources as material utilization$)",
#   "embodiedRenewableEnergy_MJ": "(^PERT$)|(^Total erneuerbare Primärenergie$)|(^Total use of renewable primary energy resources$)",
#   "nonRenewablesUsedAsEnergy_MJ": "(^Non\xadrenewable primary energy as energy carrier$)|(^PENRE$)|(^Nicht-erneuerbare Primärenergie als Energieträger$)|(^Nicht\xaderneuerbare Primärenergie als Energieträger$)|(^Non-renewable primary energy as energy carrier$)",
#   "nonRenewablesUsedAsMaterial_MJ": "(^Non\xadrenewable primary energy as material utilization$)|(^PENRM$)|(^Nicht-erneuerbare Primärenergie zur stofflichen Nutzung$)|(^Nicht\xaderneuerbare Primärenergie zur stofflichen Nutzung$)|(^Non-renewable primary energy as material utilization$)",
#   "embodiedEnergy_MJ": "(^PENRT$)|(^Total nicht erneuerbare Primärenergie$)|(^Total use of non-renewable primary energy resources$)|(^Total use of non\xadrenewable primary energy resources$)",
#   "recyclingMaterialUse_kg": "(^SM$)|(^Einsatz von Sekundärstoffen$)|(^Use of secondary material$)",
#   "renewableRecylingFuelUse_MJ": "(^RSF$)|(^Erneuerbare Sekundärbrennstoffe$)|(^Use of renewable secondary fuels$)",
#   "nonRenewableRecylingFuelUse_MJ": "(^Use of non\xadrenewable secondary fuels$)|(^NRSF$)|(^Nicht-erneuerbare Sekundärbrennstoffe$)|(^Nicht\xaderneuerbare Sekundärbrennstoffe$)|(^Use of non-renewable secondary fuels$)",
#   "cleanWaterNetUse_m3": "(^FW$)|(^Nettoeinsatz von Süßwasserressourcen$)|(^Use of net fresh water$)",
    
#   "wasteHazardous_kg": "(^HWD$)|(^Gefährlicher Abfall zur Deponie$)|(^Hazardous waste disposed$)",
#   "wasteNonHazardous_kg": "(^Non\xadhazardous waste disposed$)|(^NHWD$)|(^Entsorgter nicht gefährlicher Abfall$)|(^Non-hazardous waste disposed$)",
#   "wasteRadioactive_kg": "(^RWD$)|(^Entsorgter radioaktiver Abfall$)|(^Radioactive waste disposed$)",
#   "reusableMaterialsOutput_kg": "(^CRU$)|(^Komponenten für die Wiederverwendung$)|(^Components for re-use$)|(^Components for re\xaduse$)",
#   "recyclableMaterialsOutput_kg": "(^MFR$)|(^Stoffe zum Recycling$)|(^Materials for recycling$)",
#   "energyMaterialsOutput_kg": "(^MER$)|(^Stoffe für die Energierückgewinnung)|(^Materials for energy recovery$)",
#   "exportedEnergyOutput_MJ_electric": "(^EEE$)|(^Exportierte elektrische Energie$)|(^Exported electrical energy$)",
#   "exportedEnergyOutput_MJ_thermal": "(^EET$)|(^Exportierte thermische Energie$)|(^Exported thermal energy$)",
#   "exportedEnergyOutput_MJ": "(^EE$)",
    
#   "traciGWP_kgCO2e": 8,
#   "traciODP_kgCFC11e": 12,
#   "traciAP_kgSO2e": 6,
#   "traciEP_kgNe": 7,
#   "traciPOCP_kgO3e": 10,
#   "traciNRPE_MJ": 17
# }

# headers = [
#     "impactGWP100_kgCO2e",
#     "impactODP_kgCFC11e",
#     "impactAP_kgSO2e",
#     "impactEP_kgPO4e",
#     "impactPOCP_kgEthenee",
#     "impactADPElements_kgSbe",
#     "impactADPFossilFuels_MJ",
    
#     "renewablesUsedAsEnergy_MJ",
#     "renewablesUsedAsMaterial_MJ",
#     "embodiedRenewableEnergy_MJ",
#     "nonRenewablesUsedAsEnergy_MJ",
#     "nonRenewablesUsedAsMaterial_MJ",
#     "embodiedEnergy_MJ",
    
#     "recyclingMaterialUse_kg",
#     "renewableRecylingFuelUse_MJ",
#     "nonRenewableRecylingFuelUse_MJ",
#     "cleanWaterNetUse_m3",
#     "wasteHazardous_kg",
#     "wasteNonHazardous_kg",
#     "wasteRadioactive_kg",
#     "reusableMaterialsOutput_kg",
#     "recyclableMaterialsOutput_kg",
#     "energyMaterialsOutput_kg",
#     "exportedEnergyOutput_MJ_thermal",
#     "exportedEnergyOutput_MJ_electric",
#     "exportedEnergyOutput_MJ",
    
#     "traciGWP_kgCO2e",
#     "traciODP_kgCFC11e",
#     "traciAP_kgSO2e",
#     "traciEP_kgNe",
#     "traciPOCP_kgO3e",
#     "traciNRPE_MJ"
# ]

# columns = {
#     "impactGWP100_kgCO2e_total": "(^GWP-total$)|(^GWP - Total)|(^Global warming potential - total$)|(^Globales Erwärmungspotenzial - total$)",
#     "impactGWP100_kgCO2e_fossil": "(^GWP-fossil$)|(^GWP - Fossil)|(^Global warming potential - fossil fuels$)|(^Globales Erwärmungspotenzial - fossil$)",
#     "impactGWP100_kgCO2e_biogenic": "(^GWP-biogenic$)|(^GWP - Biogenic$)|(^Globales Erwärmungspotenzial - biogen$)",
#     "impactGWP100_kgCO2e_luluc": "(^GWP-luluc$)|(^GWP - Luluc)|(^GWP from land use and land use change$)|(^Globales Erwärmungspotenzial - luluc$)",
#     "impactODP_WMO2014_kgCFC11e": "(^ODP)|(^Depletion potential of the stratospheric ozone layer$)|(^Abbaupotenzial der stratosphärischen Ozonschicht$)",
#     "impactAP_molHeq": "(^AP)|(^Acidification potential of land and water$)|(^Versauerungspotenzial von Boden und Wasser$)|(^Versauerungspotenzial, kumulierte Überschreitung$)",
#     "impactEPFreshwater_kgPO4e": '(^Eutrophierungspotenzial - Süßwasser$)|(^EP-freshwater$)|(\*EP - Freshwater)|(^Eutrophication potential freshwater$)|($Eutrophication, fraction of nutrients reaching freshwater \nend compartment^)',
#     "impactEPFreshwater_kgP": '(^EP - Freshwater)',
#     "impactEPMarine_kgNe": '(^Eutrophierungspotenzial Salzwasser$)|(^Eutrophierungspotenzial, kumulierte Überschreitung$)|(^EP-marine$)|(^EP - Marine)|(^Eutrophication, fraction of nutrients reaching marine end \ncompartment$)|(^Eutrophication potential marine$)',
#     "impactEPTerrestrial_molNe": '(^Eutrophierungspotenzial Land$)|(^EP-terrestrial$)|(^EP - Terrestrial)|(^Eutrophication, accumulated exceedance$)|(^Eutrophierungspotenzial Land$)',
#     "impactPOCP_kgNMVOCe": '(^POCP)|(^Formation potential of tropospheric ozone photochemical oxidants$)|(^Bildungspotenzial für troposphärisches Ozon$)',
#     "cleanWaterDeprivation_m3": '(^WDP)|(^Water (user) deprivation potential$)|(^Wassernutzung$)',
#     "particulateMatter_incidence": '(^PM)|(^Potential incidence of disease due to PM emissions$)|(^Potentielles Auftreten von Krankheiten aufgrund von Feinstaubemissionen$)',
#     "ionisingRadiation_kgU235eq": '(^IR)|(^Potential Human exposure efficiency relative to U235$)|(^Potentielle Wirkung durch Exposition des Menschen mit U235$)',
#     "ecoToxicityFreshwater_CTUe": '(^ETP - FW)|(^Potential comparative Toxic Unit for ecosystems$)|(^Potentielle Toxizitätsvergleichseinheit für Ökosysteme$)',
#     "humanToxicityCancer_CTUh": '(^HTTP - C)|(^Potential comparative Toxic Unit for humans \(cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für Menschen$)',
#     "humanToxicityNonCancer_CTUh": '(^HTTP - NC)|(^Potential comparative Toxic Unit for humans \(not cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für den Menschen$)',
#     "potentialSoilQualityIndex": '(^SQP)|(^Potential soil quality index$)|(^Potentieller Bodenqualitätsindex$)',
    
#   "impactGWP100_kgCO2e": "(^GWP - Total$)|(^Global warming potential \xad total$)|(^GWP-total$)|(^GWP$)|(^Global warming potential$)|(^Globales Erwärmungspotenzial ­ total$)|(^Globales Erwärmungspotenzial$)",
#   "impactODP_kgCFC11e": "(^ODP)|((^Abbaupotenzial der stratosphärischen Ozonschicht$)|(^Depletion potential of the stratospheric ozone layer$)",
#   "impactAP_kgSO2e": "(^AP)|(^AP Air$)|(^Versauerungspotenzial von Boden und Wasser$)|(^Acidification potential of land and water$)",
#   "impactEP_kgPO4e": "(^Eutrophication, fraction of nutrients reaching freshwater \nend compartment$)|(^EP-freshwater$)|(^EP$)|(^Eutrophierungspotenzial$)|(^Eutrophication potential)",
#   "impactPOCP_kgEthenee": "(^POCP$)|(^Bildungspotenzial für troposphärisches Ozon$)|(^Formation potential of tropospheric ozone photochemical \noxidants)",
#   "impactADPElements_kgSbe": "(^ADPE)|(^Abiotic depletion potential for non\xadfossil resources$)|(^ADPE$)|(^Potenzial für die Verknappung abiotischer Ressourcen \xad \nnicht fossile Ressourcen$)|(^Potenzial für die Verknappung abiotischer Ressourcen - \nnicht fossile Ressourcen$)|(^Abiotic depletion potential for non-fossil resources)",
#   "impactADPFossilFuels_MJ": "(^ADPF)|(^Potenzial für die Verknappung abiotischer Ressourcen \xad \nfossile Brennstoffe$)|(^Potenzial für die Verknappung abiotischer Ressourcen - \nfossile Brennstoffe$)|(^Abiotic depletion potential for fossil resources)",
    
#   "renewablesUsedAsEnergy_MJ": "(^PERE)|(^Erneuerbare Primärenergie als Energieträger$)|(^Renewable primary energy as energy carrier$)",
#   "renewablesUsedAsMaterial_MJ": "(^PERM)|(^Erneuerbare Primärenergie zur stofflichen Nutzung$)|(^Renewable primary energy resources as material utilization$)",
#   "embodiedRenewableEnergy_MJ": "(^PERT)|(^Total erneuerbare Primärenergie$)|(^Total use of renewable primary energy resources$)",
#   "nonRenewablesUsedAsEnergy_MJ": "(^Non\xadrenewable primary energy as energy carrier$)|(^PENRE$)|(^Nicht-erneuerbare Primärenergie als Energieträger$)|(^Nicht\xaderneuerbare Primärenergie als Energieträger$)|(^Non-renewable primary energy as energy carrier$)",
#   "nonRenewablesUsedAsMaterial_MJ": "(^Non\xadrenewable primary energy as material utilization$)|(^PENRM$)|(^Nicht-erneuerbare Primärenergie zur stofflichen Nutzung$)|(^Nicht\xaderneuerbare Primärenergie zur stofflichen Nutzung$)|(^Non-renewable primary energy as material utilization$)",
#   "embodiedEnergy_MJ": "(^PENRT$)|(^Total nicht erneuerbare Primärenergie$)|(^Total use of non-renewable primary energy resources$)|(^Total use of non\xadrenewable primary energy resources$)",
#   "recyclingMaterialUse_kg": "(^SM$)|(^Einsatz von Sekundärstoffen$)|(^Use of secondary material$)",
#   "renewableRecylingFuelUse_MJ": "(^RSF$)|(^Erneuerbare Sekundärbrennstoffe$)|(^Use of renewable secondary fuels$)",
#   "nonRenewableRecylingFuelUse_MJ": "(^Use of non\xadrenewable secondary fuels$)|(^NRSF$)|(^Nicht-erneuerbare Sekundärbrennstoffe$)|(^Nicht\xaderneuerbare Sekundärbrennstoffe$)|(^Use of non-renewable secondary fuels$)",
#   "cleanWaterNetUse_m3": "(^FW$)|(^Nettoeinsatz von Süßwasserressourcen$)|(^Use of net fresh water$)",
    
#   "wasteHazardous_kg": "(^HWD$)|(^Gefährlicher Abfall zur Deponie$)|(^Hazardous waste disposed$)",
#   "wasteNonHazardous_kg": "(^Non\xadhazardous waste disposed$)|(^NHWD$)|(^Entsorgter nicht gefährlicher Abfall$)|(^Non-hazardous waste disposed$)",
#   "wasteRadioactive_kg": "(^RWD$)|(^Entsorgter radioaktiver Abfall$)|(^Radioactive waste disposed$)",
#   "reusableMaterialsOutput_kg": "(^CRU$)|(^Komponenten für die Wiederverwendung$)|(^Components for re-use$)|(^Components for re\xaduse$)",
#   "recyclableMaterialsOutput_kg": "(^MFR$)|(^Stoffe zum Recycling$)|(^Materials for recycling$)",
#   "energyMaterialsOutput_kg": "(^MER$)|(^Stoffe für die Energierückgewinnung)|(^Materials for energy recovery$)",
#   "exportedEnergyOutput_MJ_electric": "(^EEE$)|(^Exportierte elektrische Energie$)|(^Exported electrical energy$)",
#   "exportedEnergyOutput_MJ_thermal": "(^EET$)|(^Exportierte thermische Energie$)|(^Exported thermal energy$)",
#   "exportedEnergyOutput_MJ": "(^EE$)",
    
#   "traciGWP_kgCO2e": 8,
#   "traciODP_kgCFC11e": 12,
#   "traciAP_kgSO2e": 6,
#   "traciEP_kgNe": 7,
#   "traciPOCP_kgO3e": 10,
#   "traciNRPE_MJ": 17
# }

# headers = [
#     "impactGWP100_kgCO2e_total",
#     "impactGWP100_kgCO2e_fossil",
#     "impactGWP100_kgCO2e_biogenic",    
#     'impactGWP100_kgCO2e_luluc',
#     'impactODP_WMO2014_kgCFC11e',
#     'impactAP_molHeq',
#     'impactEPFreshwater_kgPO4e',
#     'impactEPFreshwater_kgP',
#     'impactEPMarine_kgNe',
#     'impactEPTerrestrial_molNe',
#     'impactPOCP_kgNMVOCe',
#     'cleanWaterDeprivation_m3',
#     'particulateMatter_incidence',
#     'ionisingRadiation_kgU235eq',
#     'ecoToxicityFreshwater_CTUe',
#     'humanToxicityCancer_CTUh',
#     'humanToxicityNonCancer_CTUh',
#     'potentialSoilQualityIndex',
    
#     "impactODP_kgCFC11e",
#     "impactAP_kgSO2e",
#     "impactEP_kgPO4e",
#     "impactPOCP_kgEthenee",
#     "impactADPElements_kgSbe",
#     "impactADPFossilFuels_MJ",
    
#     "renewablesUsedAsEnergy_MJ",
#     "renewablesUsedAsMaterial_MJ",
#     "embodiedRenewableEnergy_MJ",
#     "nonRenewablesUsedAsEnergy_MJ",
#     "nonRenewablesUsedAsMaterial_MJ",
#     "embodiedEnergy_MJ",
    
#     "recyclingMaterialUse_kg",
#     "renewableRecylingFuelUse_MJ",
#     "nonRenewableRecylingFuelUse_MJ",
#     "cleanWaterNetUse_m3",
#     "wasteHazardous_kg",
#     "wasteNonHazardous_kg",
#     "wasteRadioactive_kg",
#     "reusableMaterialsOutput_kg",
#     "recyclableMaterialsOutput_kg",
#     "energyMaterialsOutput_kg",
#     "exportedEnergyOutput_MJ_thermal",
#     "exportedEnergyOutput_MJ_electric",
#     "exportedEnergyOutput_MJ",
    
#     "traciGWP_kgCO2e",
#     "traciODP_kgCFC11e",
#     "traciAP_kgSO2e",
#     "traciEP_kgNe",
#     "traciPOCP_kgO3e",
#     "traciNRPE_MJ"
# ]

# %%
r[8]['dataFrame'][0][9].to_list()
# Out:
# ['Eutrophierungspotenzial, kumulierte Überschreitung',
#  'Nicht-erneuerbare Sekundärbrennstoffe']

# %%
# Versauerungspotenzial von Boden und Wasser	Eutrophierungspotenzial Süßwasser	Eutrophierungspotenzial Süßwasser
# Potentieller Bodenqualitätsindex
r[8]['dataFrame']
# Out:
#   File "<ipython-input-45-87a706240ee9>", line 2
#     Potentieller Bodenqualitätsindex
#                  ^
# SyntaxError: invalid syntax

# %%
columns = {
    "impactGWP100_kgCO2e_total": "(^GWP-total$)|(^GWP - Total)|(^Global warming potential - total$)|(^Globales Erwärmungspotenzial - total$)",
    "impactGWP100_kgCO2e_fossil": "(^GWP-fossil$)|(^GWP - Fossil)|(^Global warming potential - fossil fuels$)|(^Globales Erwärmungspotenzial - fossil$)",
    "impactGWP100_kgCO2e_biogenic": "(^GWP-biogenic$)|(^GWP - Biogenic$)|(^Globales Erwärmungspotenzial - biogen$)|(^Global warming potential - biogenic$)",
    "impactGWP100_kgCO2e_luluc": "(^GWP-luluc$)|(^GWP - Luluc)|(^GWP from land use and land use change$)|(^Globales Erwärmungspotenzial - luluc$)",
    "impactODP_WMO2014_kgCFC11e": "(^ODP)|(^Depletion potential of the stratospheric ozone layer$)|(^Abbaupotenzial der stratosphärischen Ozonschicht$)",
    "impactAP_molHeq": "(^AP)|(^Acidification potential, accumulated exceedance$)|(^Acidification potential of land and water$)|(^Versauerungspotenzial von Boden und Wasser$)|(^Versauerungspotenzial, kumulierte Überschreitung$)",
    "impactEPFreshwater_kgPO4e": '(^Eutrophierungspotenzial - Süßwasser$)|(^EP-freshwater$)|(\*EP - Freshwater)|(^Eutrophication potential freshwater$)|($Eutrophication, fraction of nutrients reaching freshwater \nend compartment^)',
    "impactEPFreshwater_kgP": '(^EP - Freshwater)',
    "impactEPMarine_kgNe": '(^Eutrophierungspotenzial Salzwasser$)|(^Eutrophierungspotenzial, kumulierte Überschreitung$)|(^EP-marine$)|(^EP - Marine)|(^Eutrophication, fraction of nutrients reaching marine end \ncompartment$)|(^Eutrophication potential marine$)',
    "impactEPTerrestrial_molNe": '(^Eutrophierungspotenzial Land$)|(^EP-terrestrial$)|(^EP - Terrestrial)|(^Eutrophication, accumulated exceedance$)|(^Eutrophierungspotenzial Land$)',
    "impactPOCP_kgNMVOCe": '(^POCP)|(^Formation potential of tropospheric ozone photochemical \noxidants$)|(^Formation potential of tropospheric ozone photochemical oxidants$)|(^Bildungspotenzial für troposphärisches Ozon$)',
    "cleanWaterDeprivation_m3": '(^WDP)|(^Water \(user\) deprivation potential, deprivation-weighted \nwater consumption \(WDP\)$)|(^Water \(user\) deprivation potential$)|(^Wassernutzung$)',
    "particulateMatter_incidence": '(^PM)|(^Potential incidence of disease due to PM emissions$)|(^Potentielles Auftreten von Krankheiten aufgrund von Feinstaubemissionen$)',
    "ionisingRadiation_kgU235eq": '(^IR)|(^Potential Human exposure efficiency relative to U235$)|(^Potentielle Wirkung durch Exposition des Menschen mit U235$)',
    "ecoToxicityFreshwater_CTUe": '(^ETP - FW)|(^Potential comparative Toxic Unit for ecosystems$)|(^Potentielle Toxizitätsvergleichseinheit für Ökosysteme$)',
    "humanToxicityCancer_CTUh": '(^HTTP - C)|(^Potential comparative Toxic Unit for humans \(cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für Menschen$)',
    "humanToxicityNonCancer_CTUh": '(^HTTP - NC)|(^Potential comparative Toxic Unit for humans \(not cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für den Menschen$)',
    "potentialSoilQualityIndex": '(^SQP)|(^Potential soil quality index$)|(^Potentieller Bodenqualitätsindex$)',
    
}

headers = [
    "impactGWP100_kgCO2e_total",
    "impactGWP100_kgCO2e_fossil",
    "impactGWP100_kgCO2e_biogenic",    
    'impactGWP100_kgCO2e_luluc',
    'impactODP_WMO2014_kgCFC11e',
    'impactAP_molHeq',
    'impactEPFreshwater_kgPO4e',
    'impactEPFreshwater_kgP',
    'impactEPMarine_kgNe',
    'impactEPTerrestrial_molNe',
    'impactPOCP_kgNMVOCe',
    'cleanWaterDeprivation_m3',
    'particulateMatter_incidence',
    'ionisingRadiation_kgU235eq',
    'ecoToxicityFreshwater_CTUe',
    'humanToxicityCancer_CTUh',
    'humanToxicityNonCancer_CTUh',
    'potentialSoilQualityIndex',
    
]

# %%
def epd_number(file_name):
    with pdfplumber.open('./Group 1 12-13-2021/' + file_name) as pdf:
        first_page = pdf.pages[0]
        text = first_page.extract_text()
        #print(text)
        item = re.findall('Declaration number.*', text)
        try:
            r = item[0].split(' ')[2]
        except:
            r = ''
        
    return r

# %%
def make_excel_file(files_data):
    book = openpyxl.Workbook()
    filename = 'test_ibu_a2.xlsx'
    book.save(filename)

    sheet = book['Sheet']
    sheet.cell(row=1, column=1).value = 'Filename'
    sheet.cell(row=1, column=2).value = 'EPD_Number'
    sheet.cell(row=1, column=3).value = 'DownloadLink'
    sheet.cell(row=1, column=4).value = 'Stages'
    
    count = 5
    for header in headers:
        sheet.cell(row=1, column=count).value = header
        count += 1
    
    current_row = 2
    for file_data in files_data:
        print(file_data["file_name"])
        print(file_data["stages"])
        print("*******************")
        df = file_data["dataFrame"]
        base_added = False
        
        for stage in file_data["stages"]:
            if not base_added:
                sheet.cell(row=current_row, column=1).value = file_data["file_name"]
                sheet.cell(row=current_row, column=2).value = epd_number(file_data["file_name"])
                sheet.cell(row=current_row, column=3).value = '/mnt/data/Downloads/2021-12-13/IBU/New/' + file_data["file_name"]
                base_added = True

            sheet.cell(row=current_row, column=4).value = stage
            header_counter = 0
            for header in headers:
                
#                 i = file_data["stages"].index(stage) + 2
#                 sheet.cell(row=current_row, column= 5 + header_counter).number_format = '0.000E+00'
#                 value = float(df[df[0].str.contains(columns2[header])][i].to_list()[0])
#                 #value = float(df[df.eq(columns[header]).any(1)][i].to_list()[0])
# #                 sheet.cell(row=current_row, column= 5 + header_counter).value = value
                try:
                    num_of_columns = len(df.columns)                    
                    i = file_data["stages"].index(stage) + (num_of_columns - len(file_data["stages"]))
                    sheet.cell(row=current_row, column= 5 + header_counter).number_format = '0.000E+00'
                    replaced = df[df[0].str.contains(columns[header])][i].to_list()[0].replace(',', '.')
                    if not replaced == 'IND':
                        try:
                            value = float(replaced)
                        except:
                            try:
                                value = float(replaced.replace('\xad', '-'))
                            except:
                                value = float(replaced.replace('\n', ''))
                    else:
                        value = replaced
                        
                    #value = float(df[df.eq(columns[header]).any(1)][i].to_list()[0])
                    sheet.cell(row=current_row, column= 5 + header_counter).value = value
                except:
                    print("**************************************ERRROR*****************************")
                    print(file_data["file_name"])
                    print(stage)
                    print(columns[header])
                header_counter= header_counter +1
            current_row = current_row + 1
        current_row = current_row + 1
            
    book.save(filename)
    book.close()

# %%
def clean_df(df):
    transformed = df.applymap(lambda x: x.split(' ') if ('E-' in x) or ('E+' in x) or (x == '') else x)
    for i in range(transformed.shape[0]):
        row = transformed.iloc[[i]]
        for index, element in row.iloc[0].items():
            if element == ['']:
                for index_s, search in row.iloc[0].items():
                    if (len(search) > 1) and ('[kg' not in search) and (type(search) == list):
                        if index < index_s:        
                            transformed.loc[i,index] = [search[0]]
                            row.iloc[0][index] = [search[0]]
                            del search[0]
                        else: 
                            transformed.loc[i,index] = [search[1]]                            
                            row.iloc[0][index] = [search[1]]
                            del search[1]
                        break
    return transformed.applymap(lambda x: x[0] if type(x) == list else x)

# %%
files = os.listdir('./Group 1 12-13-2021')
#files = ['13316.pdf', '14756.pdf']
r = []
for file in files:
    tables = camelot.read_pdf('./Group 1 12-13-2021/' + file, pages='all')
    print("************ FILE NAME: " + file + " ****************")
    dataFrames = []

    file_info = {}
    stages = []
    for table in tables:
        df = table.df
        stages_added = False
        gwp = ['GWP-total', 'Globales Erwärmungspotenzial - total','Global warming potential - total', 'Global warming potential \xad total', 'Global warming potential', 'GWP', 'Globales Erwärmungspotenzial ­ total', 'Globales Erwärmungspotenzial']
        for g in gwp:
            if (g in df.values) and ('TRACI 2.1 Impact Assessment' not in df.values):
                if not stages_added:
                    try:

                        a = list(df[df.eq('Unit').any(1)].values[0])
                        unit_index = a.index('Unit') + 1
                        stages = a[unit_index:]
                    except:
                        a = list(df[df.eq('Einheit').any(1)].values[0])
                        unit_index = a.index('Einheit') + 1
                        stages = a[unit_index:]
                    stages_added = True
                cleaned_df = clean_df(df)
                dataFrames.append(cleaned_df)


        pere = ['PERE', 'Renewable primary energy as energy carrier', 'Erneuerbare Primärenergie als Energieträger']
        for p in pere:
            if p in df.values:
                cleaned_df = clean_df(df)
                dataFrames.append(cleaned_df)

        hwd = ['HWD', 'Hazardous waste disposed', 'Gefährlicher Abfall zur Deponie']
        for h in hwd:
            if h in df.values:
                cleaned_df = clean_df(df)
                dataFrames.append(cleaned_df)

                
    result = pd.concat(dataFrames)

    file_info["dataFrame"] = result

        
    file_info["file_name"] = file
    file_info["stages"] = stages
    
    r.append(file_info)
    

make_excel_file(r)


#r
# Out:
# ************ FILE NAME: 13316.pdf ****************
# ************ FILE NAME: 14756.pdf ****************
# ************ FILE NAME: 14757.pdf ****************
# ************ FILE NAME: 14758.pdf ****************
# ************ FILE NAME: 14759.pdf ****************
# ************ FILE NAME: 14760.pdf ****************
# ************ FILE NAME: 14761.pdf ****************
# ************ FILE NAME: 14842.pdf ****************
# ************ FILE NAME: 14916.pdf ****************
# ************ FILE NAME: 14964.pdf ****************
# ************ FILE NAME: 15362.pdf ****************
# ************ FILE NAME: 15366.pdf ****************
# ************ FILE NAME: 15375.pdf ****************
# 13316.pdf
# ['A1-A3', 'A4', 'A5', 'C4', 'D']
# *******************
# **************************************ERRROR*****************************
# 13316.pdf
# A1-A3
# (^Eutrophierungspotenzial - Süßwasser$)|(^EP-freshwater$)|(\*EP - Freshwater)|(^Eutrophication potential freshwater$)|($Eutrophication, fraction of nutrients reaching freshwater
# end compartment^)
# **************************************ERRROR*****************************
# 13316.pdf
# A1-A3
# (^EP - Freshwater)
# **************************************ERRROR*****************************
# 13316.pdf
# A1-A3
# (^PM)|(^Potential incidence of disease due to PM emissions$)|(^Potentielles Auftreten von Krankheiten aufgrund von Feinstaubemissionen$)
# **************************************ERRROR*****************************
# 13316.pdf
# A1-A3
# (^IR)|(^Potential Human exposure efficiency relative to U235$)|(^Potentielle Wirkung durch Exposition des Menschen mit U235$)
# **************************************ERRROR*****************************
# 13316.pdf
# A1-A3
# (^ETP - FW)|(^Potential comparative Toxic Unit for ecosystems$)|(^Potentielle Toxizitätsvergleichseinheit für Ökosysteme$)
# **************************************ERRROR*****************************
# 13316.pdf
# A1-A3
# (^HTTP - C)|(^Potential comparative Toxic Unit for humans \(cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für Menschen$)
# **************************************ERRROR*****************************
# 13316.pdf
# A1-A3
# (^HTTP - NC)|(^Potential comparative Toxic Unit for humans \(not cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für den Menschen$)
# **************************************ERRROR*****************************
# 13316.pdf
# C:\Users\mirol\anaconda3\lib\site-packages\pandas\core\strings\accessor.py:101: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
# A1-A3
# (^SQP)|(^Potential soil quality index$)|(^Potentieller Bodenqualitätsindex$)
# **************************************ERRROR*****************************
# 13316.pdf
# A4
# (^Eutrophierungspotenzial - Süßwasser$)|(^EP-freshwater$)|(\*EP - Freshwater)|(^Eutrophication potential freshwater$)|($Eutrophication, fraction of nutrients reaching freshwater
# end compartment^)
# **************************************ERRROR*****************************
# 13316.pdf
# A4
# (^EP - Freshwater)
# **************************************ERRROR*****************************
# 13316.pdf
# A4
# (^PM)|(^Potential incidence of disease due to PM emissions$)|(^Potentielles Auftreten von Krankheiten aufgrund von Feinstaubemissionen$)
# **************************************ERRROR*****************************
# 13316.pdf
# A4
# (^IR)|(^Potential Human exposure efficiency relative to U235$)|(^Potentielle Wirkung durch Exposition des Menschen mit U235$)
# **************************************ERRROR*****************************
# 13316.pdf
# A4
# (^ETP - FW)|(^Potential comparative Toxic Unit for ecosystems$)|(^Potentielle Toxizitätsvergleichseinheit für Ökosysteme$)
# **************************************ERRROR*****************************
# 13316.pdf
# A4
# (^HTTP - C)|(^Potential comparative Toxic Unit for humans \(cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für Menschen$)
# **************************************ERRROR*****************************
# 13316.pdf
# A4
# (^HTTP - NC)|(^Potential comparative Toxic Unit for humans \(not cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für den Menschen$)
# **************************************ERRROR*****************************
# 13316.pdf
# A4
# (^SQP)|(^Potential soil quality index$)|(^Potentieller Bodenqualitätsindex$)
# **************************************ERRROR*****************************
# 13316.pdf
# A5
# (^Eutrophierungspotenzial - Süßwasser$)|(^EP-freshwater$)|(\*EP - Freshwater)|(^Eutrophication potential freshwater$)|($Eutrophication, fraction of nutrients reaching freshwater
# end compartment^)
# **************************************ERRROR*****************************
# 13316.pdf
# A5
# (^EP - Freshwater)
# **************************************ERRROR*****************************
# 13316.pdf
# A5
# (^PM)|(^Potential incidence of disease due to PM emissions$)|(^Potentielles Auftreten von Krankheiten aufgrund von Feinstaubemissionen$)
# **************************************ERRROR*****************************
# 13316.pdf
# A5
# (^IR)|(^Potential Human exposure efficiency relative to U235$)|(^Potentielle Wirkung durch Exposition des Menschen mit U235$)
# **************************************ERRROR*****************************
# 13316.pdf
# A5
# (^ETP - FW)|(^Potential comparative Toxic Unit for ecosystems$)|(^Potentielle Toxizitätsvergleichseinheit für Ökosysteme$)
# **************************************ERRROR*****************************
# 13316.pdf
# A5
# (^HTTP - C)|(^Potential comparative Toxic Unit for humans \(cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für Menschen$)
# **************************************ERRROR*****************************
# 13316.pdf
# A5
# (^HTTP - NC)|(^Potential comparative Toxic Unit for humans \(not cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für den Menschen$)
# **************************************ERRROR*****************************
# 13316.pdf
# A5
# (^SQP)|(^Potential soil quality index$)|(^Potentieller Bodenqualitätsindex$)
# **************************************ERRROR*****************************
# 13316.pdf
# C4
# (^Eutrophierungspotenzial - Süßwasser$)|(^EP-freshwater$)|(\*EP - Freshwater)|(^Eutrophication potential freshwater$)|($Eutrophication, fraction of nutrients reaching freshwater
# end compartment^)
# **************************************ERRROR*****************************
# 13316.pdf
# C4
# (^EP - Freshwater)
# **************************************ERRROR*****************************
# 13316.pdf
# C4
# (^PM)|(^Potential incidence of disease due to PM emissions$)|(^Potentielles Auftreten von Krankheiten aufgrund von Feinstaubemissionen$)
# **************************************ERRROR*****************************
# 13316.pdf
# C4
# (^IR)|(^Potential Human exposure efficiency relative to U235$)|(^Potentielle Wirkung durch Exposition des Menschen mit U235$)
# **************************************ERRROR*****************************
# 13316.pdf
# C4
# (^ETP - FW)|(^Potential comparative Toxic Unit for ecosystems$)|(^Potentielle Toxizitätsvergleichseinheit für Ökosysteme$)
# **************************************ERRROR*****************************
# 13316.pdf
# C4
# (^HTTP - C)|(^Potential comparative Toxic Unit for humans \(cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für Menschen$)
# **************************************ERRROR*****************************
# 13316.pdf
# C4
# (^HTTP - NC)|(^Potential comparative Toxic Unit for humans \(not cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für den Menschen$)
# **************************************ERRROR*****************************
# 13316.pdf
# C4
# (^SQP)|(^Potential soil quality index$)|(^Potentieller Bodenqualitätsindex$)
# **************************************ERRROR*****************************
# 13316.pdf
# D
# (^Eutrophierungspotenzial - Süßwasser$)|(^EP-freshwater$)|(\*EP - Freshwater)|(^Eutrophication potential freshwater$)|($Eutrophication, fraction of nutrients reaching freshwater
# end compartment^)
# **************************************ERRROR*****************************
# 13316.pdf
# D
# (^EP - Freshwater)
# **************************************ERRROR*****************************
# 13316.pdf
# D
# (^PM)|(^Potential incidence of disease due to PM emissions$)|(^Potentielles Auftreten von Krankheiten aufgrund von Feinstaubemissionen$)
# **************************************ERRROR*****************************
# 13316.pdf
# D
# (^IR)|(^Potential Human exposure efficiency relative to U235$)|(^Potentielle Wirkung durch Exposition des Menschen mit U235$)
# **************************************ERRROR*****************************
# 13316.pdf
# D
# (^ETP - FW)|(^Potential comparative Toxic Unit for ecosystems$)|(^Potentielle Toxizitätsvergleichseinheit für Ökosysteme$)
# **************************************ERRROR*****************************
# 13316.pdf
# D
# (^HTTP - C)|(^Potential comparative Toxic Unit for humans \(cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für Menschen$)
# **************************************ERRROR*****************************
# 13316.pdf
# D
# (^HTTP - NC)|(^Potential comparative Toxic Unit for humans \(not cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für den Menschen$)
# **************************************ERRROR*****************************
# 13316.pdf
# D
# (^SQP)|(^Potential soil quality index$)|(^Potentieller Bodenqualitätsindex$)
# 14756.pdf
# ['A1-A3', 'A4', 'A5', 'C4', 'D']
# *******************
# **************************************ERRROR*****************************
# 14756.pdf
# A1-A3
# (^Eutrophierungspotenzial - Süßwasser$)|(^EP-freshwater$)|(\*EP - Freshwater)|(^Eutrophication potential freshwater$)|($Eutrophication, fraction of nutrients reaching freshwater
# end compartment^)
# **************************************ERRROR*****************************
# 14756.pdf
# A1-A3
# (^EP - Freshwater)
# **************************************ERRROR*****************************
# 14756.pdf
# A1-A3
# (^PM)|(^Potential incidence of disease due to PM emissions$)|(^Potentielles Auftreten von Krankheiten aufgrund von Feinstaubemissionen$)
# **************************************ERRROR*****************************
# 14756.pdf
# A1-A3
# (^IR)|(^Potential Human exposure efficiency relative to U235$)|(^Potentielle Wirkung durch Exposition des Menschen mit U235$)
# **************************************ERRROR*****************************
# 14756.pdf
# A1-A3
# (^ETP - FW)|(^Potential comparative Toxic Unit for ecosystems$)|(^Potentielle Toxizitätsvergleichseinheit für Ökosysteme$)
# **************************************ERRROR*****************************
# 14756.pdf
# A1-A3
# (^HTTP - C)|(^Potential comparative Toxic Unit for humans \(cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für Menschen$)
# **************************************ERRROR*****************************
# 14756.pdf
# A1-A3
# (^HTTP - NC)|(^Potential comparative Toxic Unit for humans \(not cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für den Menschen$)
# **************************************ERRROR*****************************
# 14756.pdf
# A1-A3
# (^SQP)|(^Potential soil quality index$)|(^Potentieller Bodenqualitätsindex$)
# **************************************ERRROR*****************************
# 14756.pdf
# A4
# (^Eutrophierungspotenzial - Süßwasser$)|(^EP-freshwater$)|(\*EP - Freshwater)|(^Eutrophication potential freshwater$)|($Eutrophication, fraction of nutrients reaching freshwater
# end compartment^)
# **************************************ERRROR*****************************
# 14756.pdf
# A4
# (^EP - Freshwater)
# **************************************ERRROR*****************************
# 14756.pdf
# A4
# (^PM)|(^Potential incidence of disease due to PM emissions$)|(^Potentielles Auftreten von Krankheiten aufgrund von Feinstaubemissionen$)
# **************************************ERRROR*****************************
# 14756.pdf
# A4
# (^IR)|(^Potential Human exposure efficiency relative to U235$)|(^Potentielle Wirkung durch Exposition des Menschen mit U235$)
# **************************************ERRROR*****************************
# 14756.pdf
# A4
# (^ETP - FW)|(^Potential comparative Toxic Unit for ecosystems$)|(^Potentielle Toxizitätsvergleichseinheit für Ökosysteme$)
# **************************************ERRROR*****************************
# 14756.pdf
# A4
# (^HTTP - C)|(^Potential comparative Toxic Unit for humans \(cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für Menschen$)
# **************************************ERRROR*****************************
# 14756.pdf
# A4
# (^HTTP - NC)|(^Potential comparative Toxic Unit for humans \(not cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für den Menschen$)
# **************************************ERRROR*****************************
# 14756.pdf
# A4
# (^SQP)|(^Potential soil quality index$)|(^Potentieller Bodenqualitätsindex$)
# **************************************ERRROR*****************************
# 14756.pdf
# A5
# (^Eutrophierungspotenzial - Süßwasser$)|(^EP-freshwater$)|(\*EP - Freshwater)|(^Eutrophication potential freshwater$)|($Eutrophication, fraction of nutrients reaching freshwater
# end compartment^)
# **************************************ERRROR*****************************
# 14756.pdf
# A5
# (^EP - Freshwater)
# **************************************ERRROR*****************************
# 14756.pdf
# A5
# (^PM)|(^Potential incidence of disease due to PM emissions$)|(^Potentielles Auftreten von Krankheiten aufgrund von Feinstaubemissionen$)
# **************************************ERRROR*****************************
# 14756.pdf
# A5
# (^IR)|(^Potential Human exposure efficiency relative to U235$)|(^Potentielle Wirkung durch Exposition des Menschen mit U235$)
# **************************************ERRROR*****************************
# 14756.pdf
# A5
# (^ETP - FW)|(^Potential comparative Toxic Unit for ecosystems$)|(^Potentielle Toxizitätsvergleichseinheit für Ökosysteme$)
# **************************************ERRROR*****************************
# 14756.pdf
# A5
# (^HTTP - C)|(^Potential comparative Toxic Unit for humans \(cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für Menschen$)
# **************************************ERRROR*****************************
# 14756.pdf
# A5
# (^HTTP - NC)|(^Potential comparative Toxic Unit for humans \(not cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für den Menschen$)
# **************************************ERRROR*****************************
# 14756.pdf
# A5
# (^SQP)|(^Potential soil quality index$)|(^Potentieller Bodenqualitätsindex$)
# **************************************ERRROR*****************************
# 14756.pdf
# C4
# (^Eutrophierungspotenzial - Süßwasser$)|(^EP-freshwater$)|(\*EP - Freshwater)|(^Eutrophication potential freshwater$)|($Eutrophication, fraction of nutrients reaching freshwater
# end compartment^)
# **************************************ERRROR*****************************
# 14756.pdf
# C4
# (^EP - Freshwater)
# **************************************ERRROR*****************************
# 14756.pdf
# C4
# (^PM)|(^Potential incidence of disease due to PM emissions$)|(^Potentielles Auftreten von Krankheiten aufgrund von Feinstaubemissionen$)
# **************************************ERRROR*****************************
# 14756.pdf
# C4
# (^IR)|(^Potential Human exposure efficiency relative to U235$)|(^Potentielle Wirkung durch Exposition des Menschen mit U235$)
# **************************************ERRROR*****************************
# 14756.pdf
# C4
# (^ETP - FW)|(^Potential comparative Toxic Unit for ecosystems$)|(^Potentielle Toxizitätsvergleichseinheit für Ökosysteme$)
# **************************************ERRROR*****************************
# 14756.pdf
# C4
# (^HTTP - C)|(^Potential comparative Toxic Unit for humans \(cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für Menschen$)
# **************************************ERRROR*****************************
# 14756.pdf
# C4
# (^HTTP - NC)|(^Potential comparative Toxic Unit for humans \(not cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für den Menschen$)
# **************************************ERRROR*****************************
# 14756.pdf
# C4
# (^SQP)|(^Potential soil quality index$)|(^Potentieller Bodenqualitätsindex$)
# **************************************ERRROR*****************************
# 14756.pdf
# D
# (^Eutrophierungspotenzial - Süßwasser$)|(^EP-freshwater$)|(\*EP - Freshwater)|(^Eutrophication potential freshwater$)|($Eutrophication, fraction of nutrients reaching freshwater
# end compartment^)
# **************************************ERRROR*****************************
# 14756.pdf
# D
# (^EP - Freshwater)
# **************************************ERRROR*****************************
# 14756.pdf
# D
# (^PM)|(^Potential incidence of disease due to PM emissions$)|(^Potentielles Auftreten von Krankheiten aufgrund von Feinstaubemissionen$)
# **************************************ERRROR*****************************
# 14756.pdf
# D
# (^IR)|(^Potential Human exposure efficiency relative to U235$)|(^Potentielle Wirkung durch Exposition des Menschen mit U235$)
# **************************************ERRROR*****************************
# 14756.pdf
# D
# (^ETP - FW)|(^Potential comparative Toxic Unit for ecosystems$)|(^Potentielle Toxizitätsvergleichseinheit für Ökosysteme$)
# **************************************ERRROR*****************************
# 14756.pdf
# D
# (^HTTP - C)|(^Potential comparative Toxic Unit for humans \(cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für Menschen$)
# **************************************ERRROR*****************************
# 14756.pdf
# D
# (^HTTP - NC)|(^Potential comparative Toxic Unit for humans \(not cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für den Menschen$)
# **************************************ERRROR*****************************
# 14756.pdf
# D
# (^SQP)|(^Potential soil quality index$)|(^Potentieller Bodenqualitätsindex$)
# 14757.pdf
# ['A1-A3', 'A4', 'A5', 'C4', 'D']
# *******************
# **************************************ERRROR*****************************
# 14757.pdf
# A1-A3
# (^Eutrophierungspotenzial - Süßwasser$)|(^EP-freshwater$)|(\*EP - Freshwater)|(^Eutrophication potential freshwater$)|($Eutrophication, fraction of nutrients reaching freshwater
# end compartment^)
# **************************************ERRROR*****************************
# 14757.pdf
# A1-A3
# (^EP - Freshwater)
# **************************************ERRROR*****************************
# 14757.pdf
# A1-A3
# (^PM)|(^Potential incidence of disease due to PM emissions$)|(^Potentielles Auftreten von Krankheiten aufgrund von Feinstaubemissionen$)
# **************************************ERRROR*****************************
# 14757.pdf
# A1-A3
# (^IR)|(^Potential Human exposure efficiency relative to U235$)|(^Potentielle Wirkung durch Exposition des Menschen mit U235$)
# **************************************ERRROR*****************************
# 14757.pdf
# A1-A3
# (^ETP - FW)|(^Potential comparative Toxic Unit for ecosystems$)|(^Potentielle Toxizitätsvergleichseinheit für Ökosysteme$)
# **************************************ERRROR*****************************
# 14757.pdf
# A1-A3
# (^HTTP - C)|(^Potential comparative Toxic Unit for humans \(cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für Menschen$)
# **************************************ERRROR*****************************
# 14757.pdf
# A1-A3
# (^HTTP - NC)|(^Potential comparative Toxic Unit for humans \(not cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für den Menschen$)
# **************************************ERRROR*****************************
# 14757.pdf
# A1-A3
# (^SQP)|(^Potential soil quality index$)|(^Potentieller Bodenqualitätsindex$)
# **************************************ERRROR*****************************
# 14757.pdf
# A4
# (^Eutrophierungspotenzial - Süßwasser$)|(^EP-freshwater$)|(\*EP - Freshwater)|(^Eutrophication potential freshwater$)|($Eutrophication, fraction of nutrients reaching freshwater
# end compartment^)
# **************************************ERRROR*****************************
# 14757.pdf
# A4
# (^EP - Freshwater)
# **************************************ERRROR*****************************
# 14757.pdf
# A4
# (^PM)|(^Potential incidence of disease due to PM emissions$)|(^Potentielles Auftreten von Krankheiten aufgrund von Feinstaubemissionen$)
# **************************************ERRROR*****************************
# 14757.pdf
# A4
# (^IR)|(^Potential Human exposure efficiency relative to U235$)|(^Potentielle Wirkung durch Exposition des Menschen mit U235$)
# **************************************ERRROR*****************************
# 14757.pdf
# A4
# (^ETP - FW)|(^Potential comparative Toxic Unit for ecosystems$)|(^Potentielle Toxizitätsvergleichseinheit für Ökosysteme$)
# **************************************ERRROR*****************************
# 14757.pdf
# A4
# (^HTTP - C)|(^Potential comparative Toxic Unit for humans \(cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für Menschen$)
# **************************************ERRROR*****************************
# 14757.pdf
# A4
# (^HTTP - NC)|(^Potential comparative Toxic Unit for humans \(not cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für den Menschen$)
# **************************************ERRROR*****************************
# 14757.pdf
# A4
# (^SQP)|(^Potential soil quality index$)|(^Potentieller Bodenqualitätsindex$)
# **************************************ERRROR*****************************
# 14757.pdf
# A5
# (^Eutrophierungspotenzial - Süßwasser$)|(^EP-freshwater$)|(\*EP - Freshwater)|(^Eutrophication potential freshwater$)|($Eutrophication, fraction of nutrients reaching freshwater
# end compartment^)
# **************************************ERRROR*****************************
# 14757.pdf
# A5
# (^EP - Freshwater)
# **************************************ERRROR*****************************
# 14757.pdf
# A5
# (^PM)|(^Potential incidence of disease due to PM emissions$)|(^Potentielles Auftreten von Krankheiten aufgrund von Feinstaubemissionen$)
# **************************************ERRROR*****************************
# 14757.pdf
# A5
# (^IR)|(^Potential Human exposure efficiency relative to U235$)|(^Potentielle Wirkung durch Exposition des Menschen mit U235$)
# **************************************ERRROR*****************************
# 14757.pdf
# A5
# (^ETP - FW)|(^Potential comparative Toxic Unit for ecosystems$)|(^Potentielle Toxizitätsvergleichseinheit für Ökosysteme$)
# **************************************ERRROR*****************************
# 14757.pdf
# A5
# (^HTTP - C)|(^Potential comparative Toxic Unit for humans \(cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für Menschen$)
# **************************************ERRROR*****************************
# 14757.pdf
# A5
# (^HTTP - NC)|(^Potential comparative Toxic Unit for humans \(not cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für den Menschen$)
# **************************************ERRROR*****************************
# 14757.pdf
# A5
# (^SQP)|(^Potential soil quality index$)|(^Potentieller Bodenqualitätsindex$)
# **************************************ERRROR*****************************
# 14757.pdf
# C4
# (^Eutrophierungspotenzial - Süßwasser$)|(^EP-freshwater$)|(\*EP - Freshwater)|(^Eutrophication potential freshwater$)|($Eutrophication, fraction of nutrients reaching freshwater
# end compartment^)
# **************************************ERRROR*****************************
# 14757.pdf
# C4
# (^EP - Freshwater)
# **************************************ERRROR*****************************
# 14757.pdf
# C4
# (^PM)|(^Potential incidence of disease due to PM emissions$)|(^Potentielles Auftreten von Krankheiten aufgrund von Feinstaubemissionen$)
# **************************************ERRROR*****************************
# 14757.pdf
# C4
# (^IR)|(^Potential Human exposure efficiency relative to U235$)|(^Potentielle Wirkung durch Exposition des Menschen mit U235$)
# **************************************ERRROR*****************************
# 14757.pdf
# C4
# (^ETP - FW)|(^Potential comparative Toxic Unit for ecosystems$)|(^Potentielle Toxizitätsvergleichseinheit für Ökosysteme$)
# **************************************ERRROR*****************************
# 14757.pdf
# C4
# (^HTTP - C)|(^Potential comparative Toxic Unit for humans \(cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für Menschen$)
# **************************************ERRROR*****************************
# 14757.pdf
# C4
# (^HTTP - NC)|(^Potential comparative Toxic Unit for humans \(not cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für den Menschen$)
# **************************************ERRROR*****************************
# 14757.pdf
# C4
# (^SQP)|(^Potential soil quality index$)|(^Potentieller Bodenqualitätsindex$)
# **************************************ERRROR*****************************
# 14757.pdf
# D
# (^Eutrophierungspotenzial - Süßwasser$)|(^EP-freshwater$)|(\*EP - Freshwater)|(^Eutrophication potential freshwater$)|($Eutrophication, fraction of nutrients reaching freshwater
# end compartment^)
# **************************************ERRROR*****************************
# 14757.pdf
# D
# (^EP - Freshwater)
# **************************************ERRROR*****************************
# 14757.pdf
# D
# (^PM)|(^Potential incidence of disease due to PM emissions$)|(^Potentielles Auftreten von Krankheiten aufgrund von Feinstaubemissionen$)
# **************************************ERRROR*****************************
# 14757.pdf
# D
# (^IR)|(^Potential Human exposure efficiency relative to U235$)|(^Potentielle Wirkung durch Exposition des Menschen mit U235$)
# **************************************ERRROR*****************************
# 14757.pdf
# D
# (^ETP - FW)|(^Potential comparative Toxic Unit for ecosystems$)|(^Potentielle Toxizitätsvergleichseinheit für Ökosysteme$)
# **************************************ERRROR*****************************
# 14757.pdf
# D
# (^HTTP - C)|(^Potential comparative Toxic Unit for humans \(cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für Menschen$)
# **************************************ERRROR*****************************
# 14757.pdf
# D
# (^HTTP - NC)|(^Potential comparative Toxic Unit for humans \(not cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für den Menschen$)
# **************************************ERRROR*****************************
# 14757.pdf
# D
# (^SQP)|(^Potential soil quality index$)|(^Potentieller Bodenqualitätsindex$)
# 14758.pdf
# ['A1-A3', 'A4', 'A5', 'C4', 'D']
# *******************
# **************************************ERRROR*****************************
# 14758.pdf
# A1-A3
# (^Eutrophierungspotenzial - Süßwasser$)|(^EP-freshwater$)|(\*EP - Freshwater)|(^Eutrophication potential freshwater$)|($Eutrophication, fraction of nutrients reaching freshwater
# end compartment^)
# **************************************ERRROR*****************************
# 14758.pdf
# A1-A3
# (^EP - Freshwater)
# **************************************ERRROR*****************************
# 14758.pdf
# A1-A3
# (^PM)|(^Potential incidence of disease due to PM emissions$)|(^Potentielles Auftreten von Krankheiten aufgrund von Feinstaubemissionen$)
# **************************************ERRROR*****************************
# 14758.pdf
# A1-A3
# (^IR)|(^Potential Human exposure efficiency relative to U235$)|(^Potentielle Wirkung durch Exposition des Menschen mit U235$)
# **************************************ERRROR*****************************
# 14758.pdf
# A1-A3
# (^ETP - FW)|(^Potential comparative Toxic Unit for ecosystems$)|(^Potentielle Toxizitätsvergleichseinheit für Ökosysteme$)
# **************************************ERRROR*****************************
# 14758.pdf
# A1-A3
# (^HTTP - C)|(^Potential comparative Toxic Unit for humans \(cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für Menschen$)
# **************************************ERRROR*****************************
# 14758.pdf
# A1-A3
# (^HTTP - NC)|(^Potential comparative Toxic Unit for humans \(not cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für den Menschen$)
# **************************************ERRROR*****************************
# 14758.pdf
# A1-A3
# (^SQP)|(^Potential soil quality index$)|(^Potentieller Bodenqualitätsindex$)
# **************************************ERRROR*****************************
# 14758.pdf
# A4
# (^Eutrophierungspotenzial - Süßwasser$)|(^EP-freshwater$)|(\*EP - Freshwater)|(^Eutrophication potential freshwater$)|($Eutrophication, fraction of nutrients reaching freshwater
# end compartment^)
# **************************************ERRROR*****************************
# 14758.pdf
# A4
# (^EP - Freshwater)
# **************************************ERRROR*****************************
# 14758.pdf
# A4
# (^PM)|(^Potential incidence of disease due to PM emissions$)|(^Potentielles Auftreten von Krankheiten aufgrund von Feinstaubemissionen$)
# **************************************ERRROR*****************************
# 14758.pdf
# A4
# (^IR)|(^Potential Human exposure efficiency relative to U235$)|(^Potentielle Wirkung durch Exposition des Menschen mit U235$)
# **************************************ERRROR*****************************
# 14758.pdf
# A4
# (^ETP - FW)|(^Potential comparative Toxic Unit for ecosystems$)|(^Potentielle Toxizitätsvergleichseinheit für Ökosysteme$)
# **************************************ERRROR*****************************
# 14758.pdf
# A4
# (^HTTP - C)|(^Potential comparative Toxic Unit for humans \(cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für Menschen$)
# **************************************ERRROR*****************************
# 14758.pdf
# A4
# (^HTTP - NC)|(^Potential comparative Toxic Unit for humans \(not cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für den Menschen$)
# **************************************ERRROR*****************************
# 14758.pdf
# A4
# (^SQP)|(^Potential soil quality index$)|(^Potentieller Bodenqualitätsindex$)
# **************************************ERRROR*****************************
# 14758.pdf
# A5
# (^Eutrophierungspotenzial - Süßwasser$)|(^EP-freshwater$)|(\*EP - Freshwater)|(^Eutrophication potential freshwater$)|($Eutrophication, fraction of nutrients reaching freshwater
# end compartment^)
# **************************************ERRROR*****************************
# 14758.pdf
# A5
# (^EP - Freshwater)
# **************************************ERRROR*****************************
# 14758.pdf
# A5
# (^PM)|(^Potential incidence of disease due to PM emissions$)|(^Potentielles Auftreten von Krankheiten aufgrund von Feinstaubemissionen$)
# **************************************ERRROR*****************************
# 14758.pdf
# A5
# (^IR)|(^Potential Human exposure efficiency relative to U235$)|(^Potentielle Wirkung durch Exposition des Menschen mit U235$)
# **************************************ERRROR*****************************
# 14758.pdf
# A5
# (^ETP - FW)|(^Potential comparative Toxic Unit for ecosystems$)|(^Potentielle Toxizitätsvergleichseinheit für Ökosysteme$)
# **************************************ERRROR*****************************
# 14758.pdf
# A5
# (^HTTP - C)|(^Potential comparative Toxic Unit for humans \(cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für Menschen$)
# **************************************ERRROR*****************************
# 14758.pdf
# A5
# (^HTTP - NC)|(^Potential comparative Toxic Unit for humans \(not cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für den Menschen$)
# **************************************ERRROR*****************************
# 14758.pdf
# A5
# (^SQP)|(^Potential soil quality index$)|(^Potentieller Bodenqualitätsindex$)
# **************************************ERRROR*****************************
# 14758.pdf
# C4
# (^Eutrophierungspotenzial - Süßwasser$)|(^EP-freshwater$)|(\*EP - Freshwater)|(^Eutrophication potential freshwater$)|($Eutrophication, fraction of nutrients reaching freshwater
# end compartment^)
# **************************************ERRROR*****************************
# 14758.pdf
# C4
# (^EP - Freshwater)
# **************************************ERRROR*****************************
# 14758.pdf
# C4
# (^PM)|(^Potential incidence of disease due to PM emissions$)|(^Potentielles Auftreten von Krankheiten aufgrund von Feinstaubemissionen$)
# **************************************ERRROR*****************************
# 14758.pdf
# C4
# (^IR)|(^Potential Human exposure efficiency relative to U235$)|(^Potentielle Wirkung durch Exposition des Menschen mit U235$)
# **************************************ERRROR*****************************
# 14758.pdf
# C4
# (^ETP - FW)|(^Potential comparative Toxic Unit for ecosystems$)|(^Potentielle Toxizitätsvergleichseinheit für Ökosysteme$)
# **************************************ERRROR*****************************
# 14758.pdf
# C4
# (^HTTP - C)|(^Potential comparative Toxic Unit for humans \(cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für Menschen$)
# **************************************ERRROR*****************************
# 14758.pdf
# C4
# (^HTTP - NC)|(^Potential comparative Toxic Unit for humans \(not cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für den Menschen$)
# **************************************ERRROR*****************************
# 14758.pdf
# C4
# (^SQP)|(^Potential soil quality index$)|(^Potentieller Bodenqualitätsindex$)
# **************************************ERRROR*****************************
# 14758.pdf
# D
# (^Eutrophierungspotenzial - Süßwasser$)|(^EP-freshwater$)|(\*EP - Freshwater)|(^Eutrophication potential freshwater$)|($Eutrophication, fraction of nutrients reaching freshwater
# end compartment^)
# **************************************ERRROR*****************************
# 14758.pdf
# D
# (^EP - Freshwater)
# **************************************ERRROR*****************************
# 14758.pdf
# D
# (^PM)|(^Potential incidence of disease due to PM emissions$)|(^Potentielles Auftreten von Krankheiten aufgrund von Feinstaubemissionen$)
# **************************************ERRROR*****************************
# 14758.pdf
# D
# (^IR)|(^Potential Human exposure efficiency relative to U235$)|(^Potentielle Wirkung durch Exposition des Menschen mit U235$)
# **************************************ERRROR*****************************
# 14758.pdf
# D
# (^ETP - FW)|(^Potential comparative Toxic Unit for ecosystems$)|(^Potentielle Toxizitätsvergleichseinheit für Ökosysteme$)
# **************************************ERRROR*****************************
# 14758.pdf
# D
# (^HTTP - C)|(^Potential comparative Toxic Unit for humans \(cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für Menschen$)
# **************************************ERRROR*****************************
# 14758.pdf
# D
# (^HTTP - NC)|(^Potential comparative Toxic Unit for humans \(not cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für den Menschen$)
# **************************************ERRROR*****************************
# 14758.pdf
# D
# (^SQP)|(^Potential soil quality index$)|(^Potentieller Bodenqualitätsindex$)
# 14759.pdf
# ['A1-A3', 'A4', 'A5', 'C4', 'D']
# *******************
# **************************************ERRROR*****************************
# 14759.pdf
# A1-A3
# (^Eutrophierungspotenzial - Süßwasser$)|(^EP-freshwater$)|(\*EP - Freshwater)|(^Eutrophication potential freshwater$)|($Eutrophication, fraction of nutrients reaching freshwater
# end compartment^)
# **************************************ERRROR*****************************
# 14759.pdf
# A1-A3
# (^EP - Freshwater)
# **************************************ERRROR*****************************
# 14759.pdf
# A1-A3
# (^PM)|(^Potential incidence of disease due to PM emissions$)|(^Potentielles Auftreten von Krankheiten aufgrund von Feinstaubemissionen$)
# **************************************ERRROR*****************************
# 14759.pdf
# A1-A3
# (^IR)|(^Potential Human exposure efficiency relative to U235$)|(^Potentielle Wirkung durch Exposition des Menschen mit U235$)
# **************************************ERRROR*****************************
# 14759.pdf
# A1-A3
# (^ETP - FW)|(^Potential comparative Toxic Unit for ecosystems$)|(^Potentielle Toxizitätsvergleichseinheit für Ökosysteme$)
# **************************************ERRROR*****************************
# 14759.pdf
# A1-A3
# (^HTTP - C)|(^Potential comparative Toxic Unit for humans \(cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für Menschen$)
# **************************************ERRROR*****************************
# 14759.pdf
# A1-A3
# (^HTTP - NC)|(^Potential comparative Toxic Unit for humans \(not cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für den Menschen$)
# **************************************ERRROR*****************************
# 14759.pdf
# A1-A3
# (^SQP)|(^Potential soil quality index$)|(^Potentieller Bodenqualitätsindex$)
# **************************************ERRROR*****************************
# 14759.pdf
# A4
# (^Eutrophierungspotenzial - Süßwasser$)|(^EP-freshwater$)|(\*EP - Freshwater)|(^Eutrophication potential freshwater$)|($Eutrophication, fraction of nutrients reaching freshwater
# end compartment^)
# **************************************ERRROR*****************************
# 14759.pdf
# A4
# (^EP - Freshwater)
# **************************************ERRROR*****************************
# 14759.pdf
# A4
# (^PM)|(^Potential incidence of disease due to PM emissions$)|(^Potentielles Auftreten von Krankheiten aufgrund von Feinstaubemissionen$)
# **************************************ERRROR*****************************
# 14759.pdf
# A4
# (^IR)|(^Potential Human exposure efficiency relative to U235$)|(^Potentielle Wirkung durch Exposition des Menschen mit U235$)
# **************************************ERRROR*****************************
# 14759.pdf
# A4
# (^ETP - FW)|(^Potential comparative Toxic Unit for ecosystems$)|(^Potentielle Toxizitätsvergleichseinheit für Ökosysteme$)
# **************************************ERRROR*****************************
# 14759.pdf
# A4
# (^HTTP - C)|(^Potential comparative Toxic Unit for humans \(cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für Menschen$)
# **************************************ERRROR*****************************
# 14759.pdf
# A4
# (^HTTP - NC)|(^Potential comparative Toxic Unit for humans \(not cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für den Menschen$)
# **************************************ERRROR*****************************
# 14759.pdf
# A4
# (^SQP)|(^Potential soil quality index$)|(^Potentieller Bodenqualitätsindex$)
# **************************************ERRROR*****************************
# 14759.pdf
# A5
# (^Eutrophierungspotenzial - Süßwasser$)|(^EP-freshwater$)|(\*EP - Freshwater)|(^Eutrophication potential freshwater$)|($Eutrophication, fraction of nutrients reaching freshwater
# end compartment^)
# **************************************ERRROR*****************************
# 14759.pdf
# A5
# (^EP - Freshwater)
# **************************************ERRROR*****************************
# 14759.pdf
# A5
# (^PM)|(^Potential incidence of disease due to PM emissions$)|(^Potentielles Auftreten von Krankheiten aufgrund von Feinstaubemissionen$)
# **************************************ERRROR*****************************
# 14759.pdf
# A5
# (^IR)|(^Potential Human exposure efficiency relative to U235$)|(^Potentielle Wirkung durch Exposition des Menschen mit U235$)
# **************************************ERRROR*****************************
# 14759.pdf
# A5
# (^ETP - FW)|(^Potential comparative Toxic Unit for ecosystems$)|(^Potentielle Toxizitätsvergleichseinheit für Ökosysteme$)
# **************************************ERRROR*****************************
# 14759.pdf
# A5
# (^HTTP - C)|(^Potential comparative Toxic Unit for humans \(cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für Menschen$)
# **************************************ERRROR*****************************
# 14759.pdf
# A5
# (^HTTP - NC)|(^Potential comparative Toxic Unit for humans \(not cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für den Menschen$)
# **************************************ERRROR*****************************
# 14759.pdf
# A5
# (^SQP)|(^Potential soil quality index$)|(^Potentieller Bodenqualitätsindex$)
# **************************************ERRROR*****************************
# 14759.pdf
# C4
# (^Eutrophierungspotenzial - Süßwasser$)|(^EP-freshwater$)|(\*EP - Freshwater)|(^Eutrophication potential freshwater$)|($Eutrophication, fraction of nutrients reaching freshwater
# end compartment^)
# **************************************ERRROR*****************************
# 14759.pdf
# C4
# (^EP - Freshwater)
# **************************************ERRROR*****************************
# 14759.pdf
# C4
# (^PM)|(^Potential incidence of disease due to PM emissions$)|(^Potentielles Auftreten von Krankheiten aufgrund von Feinstaubemissionen$)
# **************************************ERRROR*****************************
# 14759.pdf
# C4
# (^IR)|(^Potential Human exposure efficiency relative to U235$)|(^Potentielle Wirkung durch Exposition des Menschen mit U235$)
# **************************************ERRROR*****************************
# 14759.pdf
# C4
# (^ETP - FW)|(^Potential comparative Toxic Unit for ecosystems$)|(^Potentielle Toxizitätsvergleichseinheit für Ökosysteme$)
# **************************************ERRROR*****************************
# 14759.pdf
# C4
# (^HTTP - C)|(^Potential comparative Toxic Unit for humans \(cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für Menschen$)
# **************************************ERRROR*****************************
# 14759.pdf
# C4
# (^HTTP - NC)|(^Potential comparative Toxic Unit for humans \(not cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für den Menschen$)
# **************************************ERRROR*****************************
# 14759.pdf
# C4
# (^SQP)|(^Potential soil quality index$)|(^Potentieller Bodenqualitätsindex$)
# **************************************ERRROR*****************************
# 14759.pdf
# D
# (^Eutrophierungspotenzial - Süßwasser$)|(^EP-freshwater$)|(\*EP - Freshwater)|(^Eutrophication potential freshwater$)|($Eutrophication, fraction of nutrients reaching freshwater
# end compartment^)
# **************************************ERRROR*****************************
# 14759.pdf
# D
# (^EP - Freshwater)
# **************************************ERRROR*****************************
# 14759.pdf
# D
# (^PM)|(^Potential incidence of disease due to PM emissions$)|(^Potentielles Auftreten von Krankheiten aufgrund von Feinstaubemissionen$)
# **************************************ERRROR*****************************
# 14759.pdf
# D
# (^IR)|(^Potential Human exposure efficiency relative to U235$)|(^Potentielle Wirkung durch Exposition des Menschen mit U235$)
# **************************************ERRROR*****************************
# 14759.pdf
# D
# (^ETP - FW)|(^Potential comparative Toxic Unit for ecosystems$)|(^Potentielle Toxizitätsvergleichseinheit für Ökosysteme$)
# **************************************ERRROR*****************************
# 14759.pdf
# D
# (^HTTP - C)|(^Potential comparative Toxic Unit for humans \(cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für Menschen$)
# **************************************ERRROR*****************************
# 14759.pdf
# D
# (^HTTP - NC)|(^Potential comparative Toxic Unit for humans \(not cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für den Menschen$)
# **************************************ERRROR*****************************
# 14759.pdf
# D
# (^SQP)|(^Potential soil quality index$)|(^Potentieller Bodenqualitätsindex$)
# 14760.pdf
# ['A1-A3', 'A4', 'A5', 'C4', 'D']
# *******************
# **************************************ERRROR*****************************
# 14760.pdf
# A1-A3
# (^Eutrophierungspotenzial - Süßwasser$)|(^EP-freshwater$)|(\*EP - Freshwater)|(^Eutrophication potential freshwater$)|($Eutrophication, fraction of nutrients reaching freshwater
# end compartment^)
# **************************************ERRROR*****************************
# 14760.pdf
# A1-A3
# (^EP - Freshwater)
# **************************************ERRROR*****************************
# 14760.pdf
# A1-A3
# (^PM)|(^Potential incidence of disease due to PM emissions$)|(^Potentielles Auftreten von Krankheiten aufgrund von Feinstaubemissionen$)
# **************************************ERRROR*****************************
# 14760.pdf
# A1-A3
# (^IR)|(^Potential Human exposure efficiency relative to U235$)|(^Potentielle Wirkung durch Exposition des Menschen mit U235$)
# **************************************ERRROR*****************************
# 14760.pdf
# A1-A3
# (^ETP - FW)|(^Potential comparative Toxic Unit for ecosystems$)|(^Potentielle Toxizitätsvergleichseinheit für Ökosysteme$)
# **************************************ERRROR*****************************
# 14760.pdf
# A1-A3
# (^HTTP - C)|(^Potential comparative Toxic Unit for humans \(cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für Menschen$)
# **************************************ERRROR*****************************
# 14760.pdf
# A1-A3
# (^HTTP - NC)|(^Potential comparative Toxic Unit for humans \(not cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für den Menschen$)
# **************************************ERRROR*****************************
# 14760.pdf
# A1-A3
# (^SQP)|(^Potential soil quality index$)|(^Potentieller Bodenqualitätsindex$)
# **************************************ERRROR*****************************
# 14760.pdf
# A4
# (^Eutrophierungspotenzial - Süßwasser$)|(^EP-freshwater$)|(\*EP - Freshwater)|(^Eutrophication potential freshwater$)|($Eutrophication, fraction of nutrients reaching freshwater
# end compartment^)
# **************************************ERRROR*****************************
# 14760.pdf
# A4
# (^EP - Freshwater)
# **************************************ERRROR*****************************
# 14760.pdf
# A4
# (^PM)|(^Potential incidence of disease due to PM emissions$)|(^Potentielles Auftreten von Krankheiten aufgrund von Feinstaubemissionen$)
# **************************************ERRROR*****************************
# 14760.pdf
# A4
# (^IR)|(^Potential Human exposure efficiency relative to U235$)|(^Potentielle Wirkung durch Exposition des Menschen mit U235$)
# **************************************ERRROR*****************************
# 14760.pdf
# A4
# (^ETP - FW)|(^Potential comparative Toxic Unit for ecosystems$)|(^Potentielle Toxizitätsvergleichseinheit für Ökosysteme$)
# **************************************ERRROR*****************************
# 14760.pdf
# A4
# (^HTTP - C)|(^Potential comparative Toxic Unit for humans \(cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für Menschen$)
# **************************************ERRROR*****************************
# 14760.pdf
# A4
# (^HTTP - NC)|(^Potential comparative Toxic Unit for humans \(not cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für den Menschen$)
# **************************************ERRROR*****************************
# 14760.pdf
# A4
# (^SQP)|(^Potential soil quality index$)|(^Potentieller Bodenqualitätsindex$)
# **************************************ERRROR*****************************
# 14760.pdf
# A5
# (^Eutrophierungspotenzial - Süßwasser$)|(^EP-freshwater$)|(\*EP - Freshwater)|(^Eutrophication potential freshwater$)|($Eutrophication, fraction of nutrients reaching freshwater
# end compartment^)
# **************************************ERRROR*****************************
# 14760.pdf
# A5
# (^EP - Freshwater)
# **************************************ERRROR*****************************
# 14760.pdf
# A5
# (^PM)|(^Potential incidence of disease due to PM emissions$)|(^Potentielles Auftreten von Krankheiten aufgrund von Feinstaubemissionen$)
# **************************************ERRROR*****************************
# 14760.pdf
# A5
# (^IR)|(^Potential Human exposure efficiency relative to U235$)|(^Potentielle Wirkung durch Exposition des Menschen mit U235$)
# **************************************ERRROR*****************************
# 14760.pdf
# A5
# (^ETP - FW)|(^Potential comparative Toxic Unit for ecosystems$)|(^Potentielle Toxizitätsvergleichseinheit für Ökosysteme$)
# **************************************ERRROR*****************************
# 14760.pdf
# A5
# (^HTTP - C)|(^Potential comparative Toxic Unit for humans \(cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für Menschen$)
# **************************************ERRROR*****************************
# 14760.pdf
# A5
# (^HTTP - NC)|(^Potential comparative Toxic Unit for humans \(not cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für den Menschen$)
# **************************************ERRROR*****************************
# 14760.pdf
# A5
# (^SQP)|(^Potential soil quality index$)|(^Potentieller Bodenqualitätsindex$)
# **************************************ERRROR*****************************
# 14760.pdf
# C4
# (^Eutrophierungspotenzial - Süßwasser$)|(^EP-freshwater$)|(\*EP - Freshwater)|(^Eutrophication potential freshwater$)|($Eutrophication, fraction of nutrients reaching freshwater
# end compartment^)
# **************************************ERRROR*****************************
# 14760.pdf
# C4
# (^EP - Freshwater)
# ...
# **************************************ERRROR*****************************
# 15375.pdf
# A5
# (^IR)|(^Potential Human exposure efficiency relative to U235$)|(^Potentielle Wirkung durch Exposition des Menschen mit U235$)
# **************************************ERRROR*****************************
# 15375.pdf
# A5
# (^ETP - FW)|(^Potential comparative Toxic Unit for ecosystems$)|(^Potentielle Toxizitätsvergleichseinheit für Ökosysteme$)
# **************************************ERRROR*****************************
# 15375.pdf
# A5
# (^HTTP - C)|(^Potential comparative Toxic Unit for humans \(cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für Menschen$)
# **************************************ERRROR*****************************
# 15375.pdf
# A5
# (^HTTP - NC)|(^Potential comparative Toxic Unit for humans \(not cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für den Menschen$)
# **************************************ERRROR*****************************
# 15375.pdf
# A5
# (^SQP)|(^Potential soil quality index$)|(^Potentieller Bodenqualitätsindex$)
# **************************************ERRROR*****************************
# 15375.pdf
# B1
# (^EP - Freshwater)
# **************************************ERRROR*****************************
# 15375.pdf
# B1
# (^POCP)|(^Formation potential of tropospheric ozone photochemical
# oxidants$)|(^Formation potential of tropospheric ozone photochemical oxidants$)|(^Bildungspotenzial für troposphärisches Ozon$)
# **************************************ERRROR*****************************
# 15375.pdf
# B1
# (^PM)|(^Potential incidence of disease due to PM emissions$)|(^Potentielles Auftreten von Krankheiten aufgrund von Feinstaubemissionen$)
# **************************************ERRROR*****************************
# 15375.pdf
# B1
# (^IR)|(^Potential Human exposure efficiency relative to U235$)|(^Potentielle Wirkung durch Exposition des Menschen mit U235$)
# **************************************ERRROR*****************************
# 15375.pdf
# B1
# (^ETP - FW)|(^Potential comparative Toxic Unit for ecosystems$)|(^Potentielle Toxizitätsvergleichseinheit für Ökosysteme$)
# **************************************ERRROR*****************************
# 15375.pdf
# B1
# (^HTTP - C)|(^Potential comparative Toxic Unit for humans \(cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für Menschen$)
# **************************************ERRROR*****************************
# 15375.pdf
# B1
# (^HTTP - NC)|(^Potential comparative Toxic Unit for humans \(not cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für den Menschen$)
# **************************************ERRROR*****************************
# 15375.pdf
# B1
# (^SQP)|(^Potential soil quality index$)|(^Potentieller Bodenqualitätsindex$)
# **************************************ERRROR*****************************
# 15375.pdf
# B2
# (^EP - Freshwater)
# **************************************ERRROR*****************************
# 15375.pdf
# B2
# (^POCP)|(^Formation potential of tropospheric ozone photochemical
# oxidants$)|(^Formation potential of tropospheric ozone photochemical oxidants$)|(^Bildungspotenzial für troposphärisches Ozon$)
# **************************************ERRROR*****************************
# 15375.pdf
# B2
# (^PM)|(^Potential incidence of disease due to PM emissions$)|(^Potentielles Auftreten von Krankheiten aufgrund von Feinstaubemissionen$)
# **************************************ERRROR*****************************
# 15375.pdf
# B2
# (^IR)|(^Potential Human exposure efficiency relative to U235$)|(^Potentielle Wirkung durch Exposition des Menschen mit U235$)
# **************************************ERRROR*****************************
# 15375.pdf
# B2
# (^ETP - FW)|(^Potential comparative Toxic Unit for ecosystems$)|(^Potentielle Toxizitätsvergleichseinheit für Ökosysteme$)
# **************************************ERRROR*****************************
# 15375.pdf
# B2
# (^HTTP - C)|(^Potential comparative Toxic Unit for humans \(cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für Menschen$)
# **************************************ERRROR*****************************
# 15375.pdf
# B2
# (^HTTP - NC)|(^Potential comparative Toxic Unit for humans \(not cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für den Menschen$)
# **************************************ERRROR*****************************
# 15375.pdf
# B2
# (^SQP)|(^Potential soil quality index$)|(^Potentieller Bodenqualitätsindex$)
# **************************************ERRROR*****************************
# 15375.pdf
# B6
# (^EP - Freshwater)
# **************************************ERRROR*****************************
# 15375.pdf
# B6
# (^POCP)|(^Formation potential of tropospheric ozone photochemical
# oxidants$)|(^Formation potential of tropospheric ozone photochemical oxidants$)|(^Bildungspotenzial für troposphärisches Ozon$)
# **************************************ERRROR*****************************
# 15375.pdf
# B6
# (^PM)|(^Potential incidence of disease due to PM emissions$)|(^Potentielles Auftreten von Krankheiten aufgrund von Feinstaubemissionen$)
# **************************************ERRROR*****************************
# 15375.pdf
# B6
# (^IR)|(^Potential Human exposure efficiency relative to U235$)|(^Potentielle Wirkung durch Exposition des Menschen mit U235$)
# **************************************ERRROR*****************************
# 15375.pdf
# B6
# (^ETP - FW)|(^Potential comparative Toxic Unit for ecosystems$)|(^Potentielle Toxizitätsvergleichseinheit für Ökosysteme$)
# **************************************ERRROR*****************************
# 15375.pdf
# B6
# (^HTTP - C)|(^Potential comparative Toxic Unit for humans \(cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für Menschen$)
# **************************************ERRROR*****************************
# 15375.pdf
# B6
# (^HTTP - NC)|(^Potential comparative Toxic Unit for humans \(not cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für den Menschen$)
# **************************************ERRROR*****************************
# 15375.pdf
# B6
# (^SQP)|(^Potential soil quality index$)|(^Potentieller Bodenqualitätsindex$)
# **************************************ERRROR*****************************
# 15375.pdf
# B7
# (^EP - Freshwater)
# **************************************ERRROR*****************************
# 15375.pdf
# B7
# (^POCP)|(^Formation potential of tropospheric ozone photochemical
# oxidants$)|(^Formation potential of tropospheric ozone photochemical oxidants$)|(^Bildungspotenzial für troposphärisches Ozon$)
# **************************************ERRROR*****************************
# 15375.pdf
# B7
# (^PM)|(^Potential incidence of disease due to PM emissions$)|(^Potentielles Auftreten von Krankheiten aufgrund von Feinstaubemissionen$)
# **************************************ERRROR*****************************
# 15375.pdf
# B7
# (^IR)|(^Potential Human exposure efficiency relative to U235$)|(^Potentielle Wirkung durch Exposition des Menschen mit U235$)
# **************************************ERRROR*****************************
# 15375.pdf
# B7
# (^ETP - FW)|(^Potential comparative Toxic Unit for ecosystems$)|(^Potentielle Toxizitätsvergleichseinheit für Ökosysteme$)
# **************************************ERRROR*****************************
# 15375.pdf
# B7
# (^HTTP - C)|(^Potential comparative Toxic Unit for humans \(cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für Menschen$)
# **************************************ERRROR*****************************
# 15375.pdf
# B7
# (^HTTP - NC)|(^Potential comparative Toxic Unit for humans \(not cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für den Menschen$)
# **************************************ERRROR*****************************
# 15375.pdf
# B7
# (^SQP)|(^Potential soil quality index$)|(^Potentieller Bodenqualitätsindex$)
# **************************************ERRROR*****************************
# 15375.pdf
# C1
# (^EP - Freshwater)
# **************************************ERRROR*****************************
# 15375.pdf
# C1
# (^POCP)|(^Formation potential of tropospheric ozone photochemical
# oxidants$)|(^Formation potential of tropospheric ozone photochemical oxidants$)|(^Bildungspotenzial für troposphärisches Ozon$)
# **************************************ERRROR*****************************
# 15375.pdf
# C1
# (^PM)|(^Potential incidence of disease due to PM emissions$)|(^Potentielles Auftreten von Krankheiten aufgrund von Feinstaubemissionen$)
# **************************************ERRROR*****************************
# 15375.pdf
# C1
# (^IR)|(^Potential Human exposure efficiency relative to U235$)|(^Potentielle Wirkung durch Exposition des Menschen mit U235$)
# **************************************ERRROR*****************************
# 15375.pdf
# C1
# (^ETP - FW)|(^Potential comparative Toxic Unit for ecosystems$)|(^Potentielle Toxizitätsvergleichseinheit für Ökosysteme$)
# **************************************ERRROR*****************************
# 15375.pdf
# C1
# (^HTTP - C)|(^Potential comparative Toxic Unit for humans \(cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für Menschen$)
# **************************************ERRROR*****************************
# 15375.pdf
# C1
# (^HTTP - NC)|(^Potential comparative Toxic Unit for humans \(not cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für den Menschen$)
# **************************************ERRROR*****************************
# 15375.pdf
# C1
# (^SQP)|(^Potential soil quality index$)|(^Potentieller Bodenqualitätsindex$)
# **************************************ERRROR*****************************
# 15375.pdf
# C2
# (^EP - Freshwater)
# **************************************ERRROR*****************************
# 15375.pdf
# C2
# (^POCP)|(^Formation potential of tropospheric ozone photochemical
# oxidants$)|(^Formation potential of tropospheric ozone photochemical oxidants$)|(^Bildungspotenzial für troposphärisches Ozon$)
# **************************************ERRROR*****************************
# 15375.pdf
# C2
# (^PM)|(^Potential incidence of disease due to PM emissions$)|(^Potentielles Auftreten von Krankheiten aufgrund von Feinstaubemissionen$)
# **************************************ERRROR*****************************
# 15375.pdf
# C2
# (^IR)|(^Potential Human exposure efficiency relative to U235$)|(^Potentielle Wirkung durch Exposition des Menschen mit U235$)
# **************************************ERRROR*****************************
# 15375.pdf
# C2
# (^ETP - FW)|(^Potential comparative Toxic Unit for ecosystems$)|(^Potentielle Toxizitätsvergleichseinheit für Ökosysteme$)
# **************************************ERRROR*****************************
# 15375.pdf
# C2
# (^HTTP - C)|(^Potential comparative Toxic Unit for humans \(cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für Menschen$)
# **************************************ERRROR*****************************
# 15375.pdf
# C2
# (^HTTP - NC)|(^Potential comparative Toxic Unit for humans \(not cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für den Menschen$)
# **************************************ERRROR*****************************
# 15375.pdf
# C2
# (^SQP)|(^Potential soil quality index$)|(^Potentieller Bodenqualitätsindex$)
# **************************************ERRROR*****************************
# 15375.pdf
# C3
# (^EP - Freshwater)
# **************************************ERRROR*****************************
# 15375.pdf
# C3
# (^POCP)|(^Formation potential of tropospheric ozone photochemical
# oxidants$)|(^Formation potential of tropospheric ozone photochemical oxidants$)|(^Bildungspotenzial für troposphärisches Ozon$)
# **************************************ERRROR*****************************
# 15375.pdf
# C3
# (^PM)|(^Potential incidence of disease due to PM emissions$)|(^Potentielles Auftreten von Krankheiten aufgrund von Feinstaubemissionen$)
# **************************************ERRROR*****************************
# 15375.pdf
# C3
# (^IR)|(^Potential Human exposure efficiency relative to U235$)|(^Potentielle Wirkung durch Exposition des Menschen mit U235$)
# **************************************ERRROR*****************************
# 15375.pdf
# C3
# (^ETP - FW)|(^Potential comparative Toxic Unit for ecosystems$)|(^Potentielle Toxizitätsvergleichseinheit für Ökosysteme$)
# **************************************ERRROR*****************************
# 15375.pdf
# C3
# (^HTTP - C)|(^Potential comparative Toxic Unit for humans \(cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für Menschen$)
# **************************************ERRROR*****************************
# 15375.pdf
# C3
# (^HTTP - NC)|(^Potential comparative Toxic Unit for humans \(not cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für den Menschen$)
# **************************************ERRROR*****************************
# 15375.pdf
# C3
# (^SQP)|(^Potential soil quality index$)|(^Potentieller Bodenqualitätsindex$)
# **************************************ERRROR*****************************
# 15375.pdf
# C4
# (^EP - Freshwater)
# **************************************ERRROR*****************************
# 15375.pdf
# C4
# (^POCP)|(^Formation potential of tropospheric ozone photochemical
# oxidants$)|(^Formation potential of tropospheric ozone photochemical oxidants$)|(^Bildungspotenzial für troposphärisches Ozon$)
# **************************************ERRROR*****************************
# 15375.pdf
# C4
# (^PM)|(^Potential incidence of disease due to PM emissions$)|(^Potentielles Auftreten von Krankheiten aufgrund von Feinstaubemissionen$)
# **************************************ERRROR*****************************
# 15375.pdf
# C4
# (^IR)|(^Potential Human exposure efficiency relative to U235$)|(^Potentielle Wirkung durch Exposition des Menschen mit U235$)
# **************************************ERRROR*****************************
# 15375.pdf
# C4
# (^ETP - FW)|(^Potential comparative Toxic Unit for ecosystems$)|(^Potentielle Toxizitätsvergleichseinheit für Ökosysteme$)
# **************************************ERRROR*****************************
# 15375.pdf
# C4
# (^HTTP - C)|(^Potential comparative Toxic Unit for humans \(cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für Menschen$)
# **************************************ERRROR*****************************
# 15375.pdf
# C4
# (^HTTP - NC)|(^Potential comparative Toxic Unit for humans \(not cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für den Menschen$)
# **************************************ERRROR*****************************
# 15375.pdf
# C4
# (^SQP)|(^Potential soil quality index$)|(^Potentieller Bodenqualitätsindex$)
# **************************************ERRROR*****************************
# 15375.pdf
# D
# (^EP - Freshwater)
# **************************************ERRROR*****************************
# 15375.pdf
# D
# (^POCP)|(^Formation potential of tropospheric ozone photochemical
# oxidants$)|(^Formation potential of tropospheric ozone photochemical oxidants$)|(^Bildungspotenzial für troposphärisches Ozon$)
# **************************************ERRROR*****************************
# 15375.pdf
# D
# (^PM)|(^Potential incidence of disease due to PM emissions$)|(^Potentielles Auftreten von Krankheiten aufgrund von Feinstaubemissionen$)
# **************************************ERRROR*****************************
# 15375.pdf
# D
# (^IR)|(^Potential Human exposure efficiency relative to U235$)|(^Potentielle Wirkung durch Exposition des Menschen mit U235$)
# **************************************ERRROR*****************************
# 15375.pdf
# D
# (^ETP - FW)|(^Potential comparative Toxic Unit for ecosystems$)|(^Potentielle Toxizitätsvergleichseinheit für Ökosysteme$)
# **************************************ERRROR*****************************
# 15375.pdf
# D
# (^HTTP - C)|(^Potential comparative Toxic Unit for humans \(cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für Menschen$)
# **************************************ERRROR*****************************
# 15375.pdf
# D
# (^HTTP - NC)|(^Potential comparative Toxic Unit for humans \(not cancerogenic\)$)|(^Potentielle Toxizitätsvergleichseinheit für den Menschen$)
# **************************************ERRROR*****************************
# 15375.pdf
# D
# (^SQP)|(^Potential soil quality index$)|(^Potentieller Bodenqualitätsindex$)

# %%
r[0]['dataFrame']
# Out:
#                                                     0  \
# 0                                      Core Indicator
# 1                    Global warming potential - total
# 2             Global warming potential - fossil fuels
# 3                 Global warming potential - biogenic
# 4               GWP from land use and land use change
# 5   Depletion potential of the stratospheric ozone...
# 6     Acidification potential, accumulated exceedance
# 7   Eutrophication, fraction of nutrients reaching...
# 8   Eutrophication, fraction of nutrients reaching...
# 9              Eutrophication, accumulated exceedance
# 10  Formation potential of tropospheric ozone phot...
# 11  Abiotic depletion potential for non-fossil res...
# 12   Abiotic depletion potential for fossil resources
# 13  Water (user) deprivation potential, deprivatio...
# 0                                           Indicator
# 1          Renewable primary energy as energy carrier
# 2   Renewable primary energy resources as material...
# 3     Total use of renewable primary energy resources
# 4      Non-renewable primary energy as energy carrier
# 5   Non-renewable primary energy as material utili...
# 6   Total use of non-renewable primary energy reso...
# 7                           Use of secondary material
# 8                    Use of renewable secondary fuels
# 9                Use of non-renewable secondary fuels
# 10                             Use of net fresh water
# 0                                           Indicator
# 1                            Hazardous waste disposed
# 2                        Non-hazardous waste disposed
# 3                          Radioactive waste disposed
# 4                               Components for re-use
# 5                             Materials for recycling
# 6                       Materials for energy recovery
# 7                          Exported electrical energy
# 8                             Exported thermal energy
#
#                            1         2          3          4         5  \
# 0                       Unit     A1-A3         A4         A5        C4
# 1               [kg CO2-Eq.]   2.81E-1    6.04E-3    1.85E-3   1.82E-1
# 2               [kg CO2-Eq.]   2.81E-1    5.92E-3    1.50E-4   1.82E-1
# 3               [kg CO2-Eq.]   1.78E-4    8.27E-5    1.70E-3   6.04E-6
# 4               [kg CO2-Eq.]   2.10E-4    4.02E-5    4.91E-8   9.74E-7
# 5             [kg CFC11-Eq.]  4.18E-12   4.77E-18   2.39E-19  1.36E-17
# 6               [mol H+-Eq.]   1.08E-3    6.60E-5    3.89E-7   1.81E-5
# 7               [kg PO4-Eq.]   4.41E-7    1.51E-8    3.68E-9   1.82E-9
# 8                 [kg N-Eq.]   1.72E-4    2.40E-5    1.70E-7   3.80E-6
# 9                [mol N-Eq.]   1.86E-3    2.64E-4    1.58E-6   8.49E-5
# 10            [kg NMVOC-Eq.]   6.10E-4    5.41E-5    6.85E-7   1.13E-5
# 11               [kg Sb-Eq.]   4.29E-8   4.51E-10   5.04E-12  2.06E-10
# 12                      [MJ]   6.99E+0    8.00E-2    8.54E-4   2.22E-2
# 13  [m³ world-Eq \ndeprived]   2.60E-2    7.10E-5    8.61E-5   1.67E-2
# 0                       Unit     A1-A3         A4         A5        C4
# 1                       [MJ]   6.28E-1    5.05E-3    8.75E-5   4.39E-3
# 2                       [MJ]   3.23E-4  -9.39E-15  -1.22E-16  1.82E-14
# 3                       [MJ]   6.28E-1    5.05E-3    8.75E-5   4.39E-3
# 4                       [MJ]   6.99E+0    8.01E-2    8.54E-4   2.22E-2
# 5                       [MJ]   1.55E-4    2.57E-6    1.67E-8   7.84E-7
# 6                       [MJ]   6.99E+0    8.01E-2    8.54E-4   2.22E-2
# 7                       [kg]   3.58E-3    0.00E+0    0.00E+0   0.00E+0
# 8                       [MJ]   5.65E-8    0.00E+0    0.00E+0   0.00E+0
# 9                       [MJ]   6.23E-7    0.00E+0    0.00E+0   0.00E+0
# 10                      [m³]   3.96E-3    5.56E-6    2.05E-6   3.92E-4
# 0                       Unit     A1-A3         A4         A5        C4
# 1                       [kg]   1.64E-9   4.16E-12   1.54E-13  3.96E-12
# 2                       [kg]   2.86E-3    1.30E-5    4.46E-4   7.20E-4
# 3                       [kg]   1.21E-4    5.40E-7    1.79E-8   1.26E-6
# 4                       [kg]      0.00       0.00       0.00      0.00
# 5                       [kg]      0.00       0.00       0.00      0.00
# 6                       [kg]      0.00       0.00       0.00      0.00
# 7                       [MJ]   0.00E+0    0.00E+0    1.46E-3   3.88E-1
# 8                       [MJ]   0.00E+0    0.00E+0    2.08E-3   6.98E-1
#
#             6
# 0           D
# 1    -9.61E-2
# 2    -9.56E-2
# 3    -4.49E-4
# 4    -6.03E-5
# 5   -9.89E-16
# 6    -1.18E-4
# 7    -1.14E-7
# 8    -3.45E-5
# 9    -3.70E-4
# 10   -9.72E-5
# 11   -1.48E-8
# 12   -1.65E+0
# 13   -6.55E-3
# 0           D
# 1    -3.39E-1
# 2   -6.85E-13
# 3    -3.39E-1
# 4    -1.65E+0
# 5    -5.37E-5
# 6    -1.65E+0
# 7     0.00E+0
# 8     0.00E+0
# 9     0.00E+0
# 10   -3.31E-4
# 0           D
# 1   -3.67E-10
# 2    -7.26E-4
# 3    -1.09E-4
# 4        0.00
# 5        0.00
# 6        0.00
# 7     0.00E+0
# 8     0.00E+0

# %%
'Eutrophication, accumulated exceedance' in r[0]['dataFrame'].values
# Out:
# True

# %%
print(r[0]['dataFrame'][0][7].to_list()[0])
print(r[0]['dataFrame'][0][8].to_list()[0])
# Out:
# Eutrophication, fraction of nutrients reaching freshwater
# end compartment
# Eutrophication, fraction of nutrients reaching marine end
# compartment

# %%
r[0]['dataFrame'][0][13]
# Out:
# 'Water (user) deprivation potential, deprivation-weighted \nwater consumption (WDP)'

# %%
'Eutrophication, fraction of nutrients reaching marine end \ncompartment' in r[0]['dataFrame'].values
# Out:
# True

# %%
r[0]['dataFrame']
Potential incidence of disease due to PM emissions
# Out:
#                                                     0  \
# 0                                      Core Indicator
# 1                    Global warming potential - total
# 2             Global warming potential - fossil fuels
# 3                 Global warming potential - biogenic
# 4               GWP from land use and land use change
# 5   Depletion potential of the stratospheric ozone...
# 6     Acidification potential, accumulated exceedance
# 7   Eutrophication, fraction of nutrients reaching...
# 8   Eutrophication, fraction of nutrients reaching...
# 9              Eutrophication, accumulated exceedance
# 10  Formation potential of tropospheric ozone phot...
# 11  Abiotic depletion potential for non-fossil res...
# 12   Abiotic depletion potential for fossil resources
# 13  Water (user) deprivation potential, deprivatio...
# 0                                           Indicator
# 1          Renewable primary energy as energy carrier
# 2   Renewable primary energy resources as material...
# 3     Total use of renewable primary energy resources
# 4      Non-renewable primary energy as energy carrier
# 5   Non-renewable primary energy as material utili...
# 6   Total use of non-renewable primary energy reso...
# 7                           Use of secondary material
# 8                    Use of renewable secondary fuels
# 9                Use of non-renewable secondary fuels
# 10                             Use of net fresh water
# 0                                           Indicator
# 1                            Hazardous waste disposed
# 2                        Non-hazardous waste disposed
# 3                          Radioactive waste disposed
# 4                               Components for re-use
# 5                             Materials for recycling
# 6                       Materials for energy recovery
# 7                          Exported electrical energy
# 8                             Exported thermal energy
#
#                            1         2          3          4         5  \
# 0                       Unit     A1-A3         A4         A5        C4
# 1               [kg CO2-Eq.]   2.81E-1    6.04E-3    1.85E-3   1.82E-1
# 2               [kg CO2-Eq.]   2.81E-1    5.92E-3    1.50E-4   1.82E-1
# 3               [kg CO2-Eq.]   1.78E-4    8.27E-5    1.70E-3   6.04E-6
# 4               [kg CO2-Eq.]   2.10E-4    4.02E-5    4.91E-8   9.74E-7
# 5             [kg CFC11-Eq.]  4.18E-12   4.77E-18   2.39E-19  1.36E-17
# 6               [mol H+-Eq.]   1.08E-3    6.60E-5    3.89E-7   1.81E-5
# 7               [kg PO4-Eq.]   4.41E-7    1.51E-8    3.68E-9   1.82E-9
# 8                 [kg N-Eq.]   1.72E-4    2.40E-5    1.70E-7   3.80E-6
# 9                [mol N-Eq.]   1.86E-3    2.64E-4    1.58E-6   8.49E-5
# 10            [kg NMVOC-Eq.]   6.10E-4    5.41E-5    6.85E-7   1.13E-5
# 11               [kg Sb-Eq.]   4.29E-8   4.51E-10   5.04E-12  2.06E-10
# 12                      [MJ]   6.99E+0    8.00E-2    8.54E-4   2.22E-2
# 13  [m³ world-Eq \ndeprived]   2.60E-2    7.10E-5    8.61E-5   1.67E-2
# 0                       Unit     A1-A3         A4         A5        C4
# 1                       [MJ]   6.28E-1    5.05E-3    8.75E-5   4.39E-3
# 2                       [MJ]   3.23E-4  -9.39E-15  -1.22E-16  1.82E-14
# 3                       [MJ]   6.28E-1    5.05E-3    8.75E-5   4.39E-3
# 4                       [MJ]   6.99E+0    8.01E-2    8.54E-4   2.22E-2
# 5                       [MJ]   1.55E-4    2.57E-6    1.67E-8   7.84E-7
# 6                       [MJ]   6.99E+0    8.01E-2    8.54E-4   2.22E-2
# 7                       [kg]   3.58E-3    0.00E+0    0.00E+0   0.00E+0
# 8                       [MJ]   5.65E-8    0.00E+0    0.00E+0   0.00E+0
# 9                       [MJ]   6.23E-7    0.00E+0    0.00E+0   0.00E+0
# 10                      [m³]   3.96E-3    5.56E-6    2.05E-6   3.92E-4
# 0                       Unit     A1-A3         A4         A5        C4
# 1                       [kg]   1.64E-9   4.16E-12   1.54E-13  3.96E-12
# 2                       [kg]   2.86E-3    1.30E-5    4.46E-4   7.20E-4
# 3                       [kg]   1.21E-4    5.40E-7    1.79E-8   1.26E-6
# 4                       [kg]      0.00       0.00       0.00      0.00
# 5                       [kg]      0.00       0.00       0.00      0.00
# 6                       [kg]      0.00       0.00       0.00      0.00
# 7                       [MJ]   0.00E+0    0.00E+0    1.46E-3   3.88E-1
# 8                       [MJ]   0.00E+0    0.00E+0    2.08E-3   6.98E-1
#
#             6
# 0           D
# 1    -9.61E-2
# 2    -9.56E-2
# 3    -4.49E-4
# 4    -6.03E-5
# 5   -9.89E-16
# 6    -1.18E-4
# 7    -1.14E-7
# 8    -3.45E-5
# 9    -3.70E-4
# 10   -9.72E-5
# 11   -1.48E-8
# 12   -1.65E+0
# 13   -6.55E-3
# 0           D
# 1    -3.39E-1
# 2   -6.85E-13
# 3    -3.39E-1
# 4    -1.65E+0
# 5    -5.37E-5
# 6    -1.65E+0
# 7     0.00E+0
# 8     0.00E+0
# 9     0.00E+0
# 10   -3.31E-4
# 0           D
# 1   -3.67E-10
# 2    -7.26E-4
# 3    -1.09E-4
# 4        0.00
# 5        0.00
# 6        0.00
# 7     0.00E+0
# 8     0.00E+0

# %%
r[8]['dataFrame']
# Out:
#                                                     0  \
# 0                                       Kernindikator
# 1                Globales Erwärmungspotenzial - total
# 2               Globales Erwärmungspotenzial - fossil
# 3               Globales Erwärmungspotenzial - biogen
# 4                Globales Erwärmungspotenzial - luluc
# 5    Abbaupotenzial der stratosphärischen Ozonschicht
# 6    Versauerungspotenzial, kumulierte Überschreitung
# 7                 Eutrophierungspotenzial - Süßwasser
# 8                Eutrophierungspotenzial - Salzwasser
# 9   Eutrophierungspotenzial, kumulierte Überschrei...
# 10        Bildungspotenzial für troposphärisches Ozon
# 11  Potenzial für die Verknappung abiotischer Ress...
# 12  Potenzial für die Verknappung abiotischer Ress...
# 13                 Wasser-Entzugspotenzial (Benutzer)
# 0                                           Indikator
# 1         Erneuerbare Primärenergie als Energieträger
# 2   Erneuerbare Primärenergie zur stofflichen Nutzung
# 3                     Total erneuerbare Primärenergie
# 4   Nicht-erneuerbare Primärenergie als Energieträger
# 5   Nicht-erneuerbare Primärenergie zur stoffliche...
# 6               Total nicht erneuerbare Primärenergie
# 7                         Einsatz von Sekundärstoffen
# 8                     Erneuerbare Sekundärbrennstoffe
# 9               Nicht-erneuerbare Sekundärbrennstoffe
# 10               Nettoeinsatz von Süßwasserressourcen
# 0                                           Indikator
# 1                     Gefährlicher Abfall zur Deponie
# 2                Entsorgter nicht gefährlicher Abfall
# 3                      Entsorgter radioaktiver Abfall
# 4                Komponenten für die Wiederverwendung
# 5                                Stoffe zum Recycling
# 6                 Stoffe für die Energierückgewinnung
# 7                     Exportierte elektrische Energie
# 8                      Exportierte thermische Energie
#
#                            1        2         3         4        5         6  \
# 0                    Einheit    A1-A3        C1        C2       C3        C4
# 1               [kg CO2-Äq.]  1,79E+1   1,46E-2   1,59E-2  0,00E+0   4,48E-3
# 2               [kg CO2-Äq.]  1,78E+1   1,84E-2   1,58E-2  0,00E+0   4,60E-3
# 3               [kg CO2-Äq.]  5,19E-2  -4,61E-3  -1,88E-5  0,00E+0  -1,34E-4
# 4               [kg CO2-Äq.]  5,19E-3   8,44E-4   1,29E-4  0,00E+0   1,35E-5
# 5             [kg CFC11-Äq.]  4,14E-9  7,09E-17  3,12E-18  0,00E+0  1,79E-17
# 6               [mol H+-Äq.]  4,53E-2   7,94E-5   1,61E-5  0,00E+0   3,27E-5
# 7                 [kg P-Äq.]  3,35E-5   3,12E-7   4,70E-8  0,00E+0   7,72E-9
# 8                 [kg N-Äq.]  1,14E-2   1,80E-5   5,01E-6  0,00E+0   8,50E-6
# 9                [mol N-Äq.]  1,19E-1   2,24E-4   5,97E-5  0,00E+0   9,34E-5
# 10            [kg NMVOC-Äq.]  3,23E-2   6,24E-5   1,39E-5  0,00E+0   2,58E-5
# 11               [kg Sb-Äq.]  1,66E-4   9,90E-9   1,40E-9  0,00E+0  4,34E-10
# 12                      [MJ]  1,75E+2   1,47E+0   2,11E-1  0,00E+0   6,10E-2
# 13  [m³ Welt-Äq. \nentzogen]  2,14E+0   1,33E-3   1,47E-4  0,00E+0   4,93E-4
# 0                    Einheit    A1-A3        C1        C2       C3        C4
# 1                       [MJ]  6,71E+0   9,62E-2   1,21E-2  0,00E+0   8,21E-3
# 2                       [MJ]  0,00E+0   0,00E+0   0,00E+0  0,00E+0   0,00E+0
# 3                       [MJ]  6,71E+0   9,62E-2   1,21E-2  0,00E+0   8,21E-3
# 4                       [MJ]  1,75E+2   1,48E+0   2,11E-1  0,00E+0   6,10E-2
# 5                       [MJ]  0,00E+0   0,00E+0   0,00E+0  0,00E+0   0,00E+0
# 6                       [MJ]  1,75E+2   1,48E+0   2,11E-1  0,00E+0   6,10E-2
# 7                       [kg]  2,26E-1   0,00E+0   0,00E+0  0,00E+0   0,00E+0
# 8                       [MJ]  0,00E+0   0,00E+0   0,00E+0  0,00E+0   0,00E+0
# 9                       [MJ]  0,00E+0   0,00E+0   0,00E+0  0,00E+0   0,00E+0
# 10                      [m³]  4,28E-2   1,08E-4   1,39E-5  0,00E+0   1,50E-5
# 0                    Einheit    A1-A3        C1        C2       C3        C4
# 1                       [kg]  1,71E-7  8,28E-11  1,11E-11  0,00E+0  6,48E-12
# 2                       [kg]  2,73E-1   2,49E-4   3,32E-5  0,00E+0   3,04E-1
# 3                       [kg]  1,17E-3   8,11E-6   3,84E-7  0,00E+0   6,39E-7
# 4                       [kg]  0,00E+0   0,00E+0   0,00E+0  0,00E+0   0,00E+0
# 5                       [kg]  0,00E+0   5,78E+0   0,00E+0  0,00E+0   0,00E+0
# 6                       [kg]  0,00E+0   0,00E+0   0,00E+0  0,00E+0   0,00E+0
# 7                       [MJ]  0,00E+0   0,00E+0   0,00E+0  0,00E+0   0,00E+0
# 8                       [MJ]  0,00E+0   0,00E+0   0,00E+0  0,00E+0   0,00E+0
#
#            7
# 0          D
# 1   -1,08E+1
# 2   -1,08E+1
# 3    1,89E-2
# 4   -2,55E-4
# 5   5,07E-14
# 6   -2,99E-2
# 7   -1,87E-6
# 8   -6,22E-3
# 9   -6,73E-2
# 10  -2,08E-2
# 11   2,32E-7
# 12  -7,90E+1
# 13   0,00E+0
# 0          D
# 1    1,01E+1
# 2    0,00E+0
# 3    1,01E+1
# 4   -7,99E+1
# 5    0,00E+0
# 6   -7,99E+1
# 7    5,55E+0
# 8    0,00E+0
# 9    0,00E+0
# 10  -7,29E-3
# 0          D
# 1    9,69E-9
# 2   -1,57E-1
# 3    1,30E-3
# 4    0,00E+0
# 5    0,00E+0
# 6    0,00E+0
# 7    0,00E+0
# 8    0,00E+0

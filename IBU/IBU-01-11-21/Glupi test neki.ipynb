# %%
import camelot
import pandas as pd
import openpyxl
# tables = camelot.read_pdf('epd1388_2021.pdf', pages='10',process_background=True)
# tables = camelot.read_pdf('./IBU-09-20/New/14632.pdf', pages='6', split_text=True,table_areas=["69.60548391889084,500.088593765987,525.3099336281931,403.96614296894364"])
# print(len(tables))

tables = camelot.read_pdf('./New/14699.pdf', pages='all')
print(len(tables))
# Out:
# 11

# %%
tables[7].df
# Out:
#                  0                         1         2         3         4  \
# 0   Core Indicator                      Unit     A1-A3        A4        A5
# 1        GWP-total              [kg CO2-Eq.]   5.92E+0   1.72E-2   1.02E-1
# 2       GWP-fossil              [kg CO2-Eq.]   5.93E+0   1.65E-2   2.54E-3
# 3     GWP-biogenic              [kg CO2-Eq.]  -1.66E-2   7.26E-4   9.90E-2
# 4        GWP-luluc              [kg CO2-Eq.]   8.99E-3   3.90E-7   1.67E-6
# 5              ODP            [kg CFC11-Eq.]  7.77E-10  1.73E-18  1.83E-17
# 6               AP              [mol H+-Eq.]   3.33E-2   4.58E-5   2.84E-5
# 7    EP-freshwater                [kg P-Eq.]   4.30E-5   3.54E-9   3.58E-9
# 8        EP-marine                [kg N-Eq.]   5.84E-3   1.29E-5   1.03E-5
# 9   EP-terrestrial               [mol N-Eq.]   6.22E-2   1.43E-4   1.28E-4
# 10            POCP            [kg NMVOC-Eq.]   1.71E-2   3.63E-5   2.72E-5
# ...

# %%
df = tables[7].df

# %%
df[df[0].str.contains("(^GWP-total$)|(^GWP$)|(^Global warming potential)|(^Globales Erwärmungspotenzial ­ total)|(Globales Erwärmungspotenzial)")]
# Out:
# C:\Users\mirol\anaconda3\lib\site-packages\pandas\core\strings\accessor.py:101: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
#            0             1        2        3        4        5        6  \
# 1  GWP-total  [kg CO2-Eq.]  5.92E+0  1.72E-2  1.02E-1  4.13E+2  7.82E-4
#
#          7        8         9
# 1  2.20E-1  6.87E-5  -3.59E-1

# %%
tables = camelot.read_pdf('./New/15186.pdf', pages='all')

# %%
tables[13].df
# Out:
#                                0     1        2        3         4
# 0                      Parameter  Unit    A1-A3       C3         D
# 1       Hazardous waste disposed  [kg]  4.86E-2  3.28E-7  -1.89E-1
# 2   Non-hazardous waste disposed  [kg]  3.41E+2  5.01E+1   1.99E+1
# 3     Radioactive waste disposed  [kg]  2.31E+0  4.80E-3  -1.54E-1
# 4          Components for re-use  [kg]  0.00E+0  0.00E+0   0.00E+0
# 5        Materials for recycling  [kg]  0.00E+0  9.50E+2   0.00E+0
# 6  Materials for energy recovery  [kg]  0.00E+0  0.00E+0   0.00E+0
# 7     Exported electrical energy  [MJ]  0.00E+0  0.00E+0   0.00E+0
# 8        Exported thermal energy  [MJ]  0.00E+0  0.00E+0   0.00E+0

# %%
df = tables[13].df

# %%
df[0][8]
# Out:
# 'Exported thermal energy'

# %%
'TRACI 2.1 Impact Assessment' not in tables[10].df.values
# Out:
# False

# %%
df = tables[5].df

# %%
df[df[0].str.contains("(^GWP-total$)|(^GWP$)|(^Global warming potential$)|(^Globales Erwärmungspotenzial ­ total$)|(^Globales Erwärmungspotenzial$)")]
# Out:
# C:\Users\mirol\anaconda3\lib\site-packages\pandas\core\strings\accessor.py:101: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
#                               0             1     2
# 1  Globales Erwärmungspotenzial  [kg CO2-Äq.]  1,35

# %%
df[df[0].str.contains("ADPF")]
# Out:
#      0     1  2                                        3  4  5  6        7   \
# 7  ADPF  [MJ]     1.17E+2 2.88E+0 3.68E+0 0.00E+0 6.76E+0           1.61E-1
#
#   8                                                  9  10 11 12 13 14
# 7     2.23E+0 2.84E+0 3.60E+0 -8.84E-1 0.00E+0 -1.06...

# %%
tables = camelot.read_pdf('./New/14417.pdf', pages='all')

# %%
tables[7].df
# Out:
#                                                    0                 1  \
# 0                                          Parameter           Einheit
# 1                       Globales Erwärmungspotenzial      [kg CO2­Äq.]
# 2   Abbaupotenzial der stratosphärischen Ozonschicht    [kg CFC11­Äq.]
# 3         Versauerungspotenzial von Boden und Wasser      [kg SO2­Äq.]
# 4                            Eutrophierungspotenzial  [kg (PO4)3­­Äq.]
# 5        Bildungspotenzial für troposphärisches Ozon    [kg Ethen­Äq.]
# 6  Potenzial für die Verknappung abiotischer Ress...       [kg Sb­Äq.]
# 7  Potenzial für die Verknappung abiotischer Ress...              [MJ]
#
#          2         3
# 0    A1­A3        A4
# 1  2,09E+2   1,31E+1
# 2  6,06E­9  1,61E­11
# 3  3,09E­1   3,41E­2
# 4  3,64E­2   9,58E­3
# 5  3,95E­2  ­1,00E­2
# 6  4,59E­4   6,76E­7
# 7  1,21E+3   1,78E+2

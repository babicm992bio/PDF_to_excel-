# %%
import camelot
import pandas as pd
import openpyxl
import os
# tables = camelot.read_pdf('epd1388_2021.pdf', pages='10',process_background=True)
# tables = camelot.read_pdf('./IBU-09-20/New/14632.pdf', pages='6', split_text=True,table_areas=["69.60548391889084,500.088593765987,525.3099336281931,403.96614296894364"])
# print(len(tables))

tables = camelot.read_pdf('./1/epd5036.pdf', pages='all')
print(len(tables))
# Out:
# ---------------------------------------------------------------------------
# PdfReadError                              Traceback (most recent call last)
# <ipython-input-29-a1679130a1c1> in <module>
#       7 # print(len(tables))
#       8
# ----> 9 tables = camelot.read_pdf('./1/epd5036.pdf', pages='all')
#      10 print(len(tables))
#
# ~\anaconda3\lib\site-packages\camelot\io.py in read_pdf(filepath, pages, password, flavor, suppress_stdout, layout_kwargs, **kwargs)
#     109
#     110         validate_input(kwargs, flavor=flavor)
# --> 111         p = PDFHandler(filepath, pages=pages, password=password)
#     112         kwargs = remove_extra(kwargs, flavor=flavor)
#     113         tables = p.parse(
#
# ~\anaconda3\lib\site-packages\camelot\handlers.py in __init__(self, filepath, pages, password)
#      48             if sys.version_info[0] < 3:
#      49                 self.password = self.password.encode("ascii")
# ---> 50         self.pages = self._get_pages(self.filepath, pages)
#      51
#      52     def _get_pages(self, filepath, pages):
#
# ~\anaconda3\lib\site-packages\camelot\handlers.py in _get_pages(self, filepath, pages)
#      72         else:
#      73             instream = open(filepath, "rb")
# ---> 74             infile = PdfFileReader(instream, strict=False)
#      75             if infile.isEncrypted:
#      76                 infile.decrypt(self.password)
#
# ~\anaconda3\lib\site-packages\PyPDF2\pdf.py in __init__(self, stream, strict, warndest, overwriteWarnings)
#    1082             stream = BytesIO(b_(fileobj.read()))
#    1083             fileobj.close()
# -> 1084         self.read(stream)
#    1085         self.stream = stream
#    1086
#
# ~\anaconda3\lib\site-packages\PyPDF2\pdf.py in read(self, stream)
#    1694         while line[:5] != b_("%%EOF"):
#    1695             if stream.tell() < last1K:
# -> 1696                 raise utils.PdfReadError("EOF marker not found")
#    1697             line = self.readNextEndLine(stream)
#    1698             if debug: print("  line:",line)
#
# PdfReadError: EOF marker not found

# %%
'PERE' in tables[4].df.values
# Out:
# True

# %%
'GWP-total' in tables[3].df.values
# Out:
# True

# %%
tables[3].df[0][1]
# Out:
# 'GWP-total'

# %%
'GWP\xadtotal' in tables[3].df
# Out:
# False

# %%
'AP' in tables[3].df[0]
# Out:
# False

# %%
tables[3].df
# Out:
#                                                    0                       1   \
# 0   Parameter \nUnit \nA1 \nA2 \nA3 \nC1 \nC2 \nC3...
# 1                                           GWP-total               kg CO2 eq
# 2                                          GWP-fossil               kg CO2 eq
# 3                                        GWP-biogenic               kg CO2 eq
# 4                                           GWP-luluc               kg CO2 eq
# 5                                                 ODP             kg CFC11 eq
# 6                                                  AP               mol H+ eq
# 7                                       EP-freshwater                 kg P eq
# 8                                       EP-freshwater            kg PO4\n3-eq
# 9                                           EP-marine                 kg N eq
# 10                                     EP-terrestrial                mol N eq
# 11                                               POCP             kg NMVOC eq
# 12                            ADP – \nmineral&metals*                kg Sb eq
# 13                                      ADP – fossil*                      MJ
# 14                                               WDP*  m3 world eq. \ndepriv.
# 15                                            GWP GHG               kg CO2 eq
#
#           2         3         4         5         6         7         8   \
# 0
# 1   8,51E+00  1,42E-01  1,12E-01  1,41E-01  5,91E-02  0,00E+00  4,49E-01
# 2   8,01E+00  1,42E-01  9,12E-02  1,41E-01  5,91E-02  0,00E+00  4,49E-01
# 3   5,21E-01  4,02E-05  2,11E-02  2,25E-05  1,69E-05  0,00E+00  1,35E-04
# 4   3,91E-03  4,22E-05  2,59E-04  1,19E-05  1,74E-05  0,00E+00  6,28E-06
# 5   8,02E-07  3,26E-08  5,79E-09  3,17E-08  1,37E-08  0,00E+00  4,96E-09
# 6   2,02E-01  4,09E-04  3,14E-04  9,04E-04  3,01E-04  0,00E+00  1,69E-04
# 7   2,81E-02  1,16E-05  2,48E-05  6,43E-06  4,78E-06  0,00E+00  2,39E-06
# 8   8,61E-02  3,55E-05  7,61E-05  1,97E-05  1,47E-05  0,00E+00  7,35E-06
# 9   1,70E-02  7,83E-05  1,19E-04  3,64E-04  1,02E-04  0,00E+00  1,74E-04
# 10  2,93E-01  8,70E-04  8,66E-04  4,00E-03  1,12E-03  0,00E+00  7,30E-04
# 11  4,24E-02  3,31E-04  2,33E-04  1,12E-03  3,16E-04  0,00E+00  2,08E-04
# 12  1,59E-03  4,30E-07  9,25E-08  4,68E-08  1,77E-07  0,00E+00  5,26E-08
# 13  1,49E+02  2,17E+00  1,21E+00  2,03E+00  9,08E-01  0,00E+00  3,47E-01
# 14  2,65E+00  1,49E-02  2,84E-02  1,09E-02  6,18E-03  0,00E+00  9,78E-03
# 15  8,15E+00  1,42E-01  1,05E-01  1,41E-01  5,91E-02  0,00E+00  4,49E-01
#
#           9          10
# 0
# 1   9,41E+00  -3,82E-01
# 2   8,89E+00  -3,61E-01
# 3   5,43E-01  -1,51E-02
# 4   4,25E-03  -5,67E-03
# 5   8,91E-07  -7,07E-08
# 6   2,04E-01  -3,33E-03
# 7   2,81E-02  -8,26E-05
# 8   8,63E-02  -2,54E-04
# 9   1,78E-02  -3,38E-04
# 10  3,01E-01  -9,51E-03
# 11  4,46E-02  -2,09E-03
# 12  1,59E-03  -5,78E-07
# 13  1,56E+02  -1,00E+01
# 14  2,72E+00  -1,25E-01
# 15  9,04E+00  -3,71E-01

# %%
df = tables[3].df

# %%
df
# Out:
#                                                    0                       1   \
# 0   Parameter \nUnit \nA1 \nA2 \nA3 \nC1 \nC2 \nC3...
# 1                                           GWP-total               kg CO2 eq
# 2                                          GWP-fossil               kg CO2 eq
# 3                                        GWP-biogenic               kg CO2 eq
# 4                                           GWP-luluc               kg CO2 eq
# 5                                                 ODP             kg CFC11 eq
# 6                                                  AP               mol H+ eq
# 7                                       EP-freshwater                 kg P eq
# 8                                       EP-freshwater            kg PO4\n3-eq
# 9                                           EP-marine                 kg N eq
# 10                                     EP-terrestrial                mol N eq
# 11                                               POCP             kg NMVOC eq
# 12                            ADP – \nmineral&metals*                kg Sb eq
# 13                                      ADP – fossil*                      MJ
# 14                                               WDP*  m3 world eq. \ndepriv.
# 15                                            GWP GHG               kg CO2 eq
#
#           2         3         4         5         6         7         8   \
# 0
# 1   8,51E+00  1,42E-01  1,12E-01  1,41E-01  5,91E-02  0,00E+00  4,49E-01
# 2   8,01E+00  1,42E-01  9,12E-02  1,41E-01  5,91E-02  0,00E+00  4,49E-01
# 3   5,21E-01  4,02E-05  2,11E-02  2,25E-05  1,69E-05  0,00E+00  1,35E-04
# 4   3,91E-03  4,22E-05  2,59E-04  1,19E-05  1,74E-05  0,00E+00  6,28E-06
# 5   8,02E-07  3,26E-08  5,79E-09  3,17E-08  1,37E-08  0,00E+00  4,96E-09
# 6   2,02E-01  4,09E-04  3,14E-04  9,04E-04  3,01E-04  0,00E+00  1,69E-04
# 7   2,81E-02  1,16E-05  2,48E-05  6,43E-06  4,78E-06  0,00E+00  2,39E-06
# 8   8,61E-02  3,55E-05  7,61E-05  1,97E-05  1,47E-05  0,00E+00  7,35E-06
# 9   1,70E-02  7,83E-05  1,19E-04  3,64E-04  1,02E-04  0,00E+00  1,74E-04
# 10  2,93E-01  8,70E-04  8,66E-04  4,00E-03  1,12E-03  0,00E+00  7,30E-04
# 11  4,24E-02  3,31E-04  2,33E-04  1,12E-03  3,16E-04  0,00E+00  2,08E-04
# 12  1,59E-03  4,30E-07  9,25E-08  4,68E-08  1,77E-07  0,00E+00  5,26E-08
# 13  1,49E+02  2,17E+00  1,21E+00  2,03E+00  9,08E-01  0,00E+00  3,47E-01
# 14  2,65E+00  1,49E-02  2,84E-02  1,09E-02  6,18E-03  0,00E+00  9,78E-03
# 15  8,15E+00  1,42E-01  1,05E-01  1,41E-01  5,91E-02  0,00E+00  4,49E-01
#
#           9          10
# 0
# 1   9,41E+00  -3,82E-01
# 2   8,89E+00  -3,61E-01
# 3   5,43E-01  -1,51E-02
# 4   4,25E-03  -5,67E-03
# 5   8,91E-07  -7,07E-08
# 6   2,04E-01  -3,33E-03
# 7   2,81E-02  -8,26E-05
# 8   8,63E-02  -2,54E-04
# 9   1,78E-02  -3,38E-04
# 10  3,01E-01  -9,51E-03
# 11  4,46E-02  -2,09E-03
# 12  1,59E-03  -5,78E-07
# 13  1,56E+02  -1,00E+01
# 14  2,72E+00  -1,25E-01
# 15  9,04E+00  -3,71E-01

# %%
df.values
# Out:
# array([['Parameter \nUnit \nA1 \nA2 \nA3 \nC1 \nC2 \nC3 \nC4 \nTotal \nD',
#         '', '', '', '', '', '', '', '', '', ''],
#        ['GWP-total', 'kg CO2 eq', '8,51E+00', '1,42E-01', '1,12E-01',
#         '1,41E-01', '5,91E-02', '0,00E+00', '4,49E-01', '9,41E+00',
#         '-3,82E-01'],
#        ['GWP-fossil', 'kg CO2 eq', '8,01E+00', '1,42E-01', '9,12E-02',
#         '1,41E-01', '5,91E-02', '0,00E+00', '4,49E-01', '8,89E+00',
#         '-3,61E-01'],
#        ['GWP-biogenic', 'kg CO2 eq', '5,21E-01', '4,02E-05', '2,11E-02',
#         '2,25E-05', '1,69E-05', '0,00E+00', '1,35E-04', '5,43E-01',
#         '-1,51E-02'],
#        ['GWP-luluc', 'kg CO2 eq', '3,91E-03', '4,22E-05', '2,59E-04',
#         '1,19E-05', '1,74E-05', '0,00E+00', '6,28E-06', '4,25E-03',
#         '-5,67E-03'],
#        ['ODP', 'kg CFC11 eq', '8,02E-07', '3,26E-08', '5,79E-09',
#         '3,17E-08', '1,37E-08', '0,00E+00', '4,96E-09', '8,91E-07',
#         '-7,07E-08'],
#        ['AP', 'mol H+ eq', '2,02E-01', '4,09E-04', '3,14E-04',
#         '9,04E-04', '3,01E-04', '0,00E+00', '1,69E-04', '2,04E-01',
#         '-3,33E-03'],
#        ['EP-freshwater', 'kg P eq', '2,81E-02', '1,16E-05', '2,48E-05',
#         '6,43E-06', '4,78E-06', '0,00E+00', '2,39E-06', '2,81E-02',
#         '-8,26E-05'],
#        ['EP-freshwater', 'kg PO4\n3-eq', '8,61E-02', '3,55E-05',
#         '7,61E-05', '1,97E-05', '1,47E-05', '0,00E+00', '7,35E-06',
#         '8,63E-02', '-2,54E-04'],
#        ['EP-marine', 'kg N eq', '1,70E-02', '7,83E-05', '1,19E-04',
#         '3,64E-04', '1,02E-04', '0,00E+00', '1,74E-04', '1,78E-02',
#         '-3,38E-04'],
#        ['EP-terrestrial', 'mol N eq', '2,93E-01', '8,70E-04', '8,66E-04',
#         '4,00E-03', '1,12E-03', '0,00E+00', '7,30E-04', '3,01E-01',
#         '-9,51E-03'],
#        ['POCP', 'kg NMVOC eq', '4,24E-02', '3,31E-04', '2,33E-04',
#         '1,12E-03', '3,16E-04', '0,00E+00', '2,08E-04', '4,46E-02',
#         '-2,09E-03'],
#        ['ADP – \nmineral&metals*', 'kg Sb eq', '1,59E-03', '4,30E-07',
#         '9,25E-08', '4,68E-08', '1,77E-07', '0,00E+00', '5,26E-08',
#         '1,59E-03', '-5,78E-07'],
#        ['ADP – fossil*', 'MJ', '1,49E+02', '2,17E+00', '1,21E+00',
#         '2,03E+00', '9,08E-01', '0,00E+00', '3,47E-01', '1,56E+02',
#         '-1,00E+01'],
#        ['WDP*', 'm3 world eq. \ndepriv.', '2,65E+00', '1,49E-02',
#         '2,84E-02', '1,09E-02', '6,18E-03', '0,00E+00', '9,78E-03',
#         '2,72E+00', '-1,25E-01'],
#        ['GWP GHG', 'kg CO2 eq', '8,15E+00', '1,42E-01', '1,05E-01',
#         '1,41E-01', '5,91E-02', '0,00E+00', '4,49E-01', '9,04E+00',
#         '-3,71E-01']], dtype=object)
